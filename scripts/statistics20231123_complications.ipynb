# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

from utils import load_env_file, set_mpl_configs
from utils import leave_percentile, distribution_analysis
from utils_statistics import construct_chi2_test, construct_fisher_test
from utils_complications import batch_query_by_subject_id

load_env_file()
set_mpl_configs()

DATA_DIR = os.getenv('DATA_DIR')
print('DATA_DIR: {}'.format(DATA_DIR))
# Out:
# load env file
#   root dir:
#     /Users/k/Repo/gp-ibd
#   current system:
#     Darwin
#   load .env.darwin
#   loaded data dir:
#     /Users/k/Nutstore Files/毕设-EHR/DB
# done.
# set matplotlib configs
#   font family:
#     ['Times New Roman']
# done.
# DATA_DIR: /Users/k/Nutstore Files/毕设-EHR/DB

# %%
df_ibd = pd.read_csv(os.path.join(DATA_DIR, 'complication', 'Complications_Patients.csv'))
df_no_ibd = pd.read_csv(os.path.join(DATA_DIR, 'complication', 'Complications_Patients_NoIBD.csv'))
df_no_ibd.head(10)
# Out:
#    subject_id   hadm_id  seq_num icd_code  icd_version  subject_id.1 gender  \
# 0    10000032  22595853        1     5723            9      10000032      F
# 1    10000032  22595853        2    78959            9      10000032      F
# 2    10000032  22595853        3     5715            9      10000032      F
# 3    10000032  22595853        4    07070            9      10000032      F
# 4    10000032  22595853        5      496            9      10000032      F
# 5    10000032  22595853        6    29680            9      10000032      F
# 6    10000032  22595853        7    30981            9      10000032      F
# 7    10000032  22595853        8    V1582            9      10000032      F
# 8    10000032  22841357        1    07071            9      10000032      F
# 9    10000032  22841357        2    78959            9      10000032      F
#
#    anchor_age  anchor_year anchor_year_group         dod
# 0          52         2180       2014 - 2016  2180-09-09
# 1          52         2180       2014 - 2016  2180-09-09
# 2          52         2180       2014 - 2016  2180-09-09
# 3          52         2180       2014 - 2016  2180-09-09
# 4          52         2180       2014 - 2016  2180-09-09
# 5          52         2180       2014 - 2016  2180-09-09
# 6          52         2180       2014 - 2016  2180-09-09
# 7          52         2180       2014 - 2016  2180-09-09
# 8          52         2180       2014 - 2016  2180-09-09
# 9          52         2180       2014 - 2016  2180-09-09

# %%
stats = df_ibd.groupby('subject_id').agg({
    'gender': 'first',
    'anchor_age': 'first',
    'anchor_year': 'first',
    'dod': 'first',
    'seq_num': ['count'],
    # 'icd_code': 'unique'
})

live = stats[stats['dod']['first'].isnull()]
dead = stats[stats['dod']['first'].notnull()]
print(live.shape[0], dead.shape[0])

live_df = batch_query_by_subject_id(_df=df_ibd, _subject_ids=live.index.to_list())
dead_df = batch_query_by_subject_id(_df=df_ibd, _subject_ids=dead.index.to_list())
# Out:
# 2037 380

# %%
suspect_icd_codes = ['2724', '27651', '2859', '30000', '311', '4019', '53081', '5849', 'V1582']

for suspect_icd_code in suspect_icd_codes:
    print('--> Suspect ICD Code: {}'.format(suspect_icd_code))
    pvalue1 = construct_chi2_test(live_df, dead_df, suspect_icd_code, silent=True)
    pvalue2 = construct_fisher_test(live_df, dead_df, suspect_icd_code, silent=True)

    if pvalue1 <= 0.05 or pvalue2 <= 0.05:
        print('  chi2 test pvalue:\n    {:.8f}'.format(pvalue1))
        print('  fisher test pvalue:\n    {:.8f}'.format(pvalue2))
        pvalue1 = construct_chi2_test(live_df, dead_df, suspect_icd_code, silent=False)
        pvalue2 = construct_fisher_test(live_df, dead_df, suspect_icd_code, silent=False)

    
    # break
# Out:
# --> Suspect ICD Code: 2724
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     329.0000    1708.0000
#     162.0000    218.0000
#   expected:
#     413.8051    1623.1949
#     77.1949    302.8051
#   chi2: 137.0962
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     329.0000    1708.0000
#     162.0000    218.0000
#   oddsratio: 0.2592
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 27651
#   chi2 test pvalue:
#     0.00000003
#   fisher test pvalue:
#     0.00000009
# start chi2 test
#   observed:
#     307.0000    1730.0000
#     102.0000    278.0000
#   expected:
#     344.6971    1692.3029
#     64.3029    315.6971
#   chi2: 30.7318
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     307.0000    1730.0000
#     102.0000    278.0000
#   oddsratio: 0.4837
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 2859
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     377.0000    1660.0000
#     146.0000    234.0000
#   expected:
#     440.7741    1596.2259
#     82.2259    297.7741
#   chi2: 73.7268
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     377.0000    1660.0000
#     146.0000    234.0000
#   oddsratio: 0.3640
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 30000
# --> Suspect ICD Code: 311
#   chi2 test pvalue:
#     0.00000023
#   fisher test pvalue:
#     0.00000043
# start chi2 test
#   observed:
#     385.0000    1652.0000
#     117.0000    263.0000
#   expected:
#     423.0757    1613.9243
#     78.9243    301.0757
#   chi2: 26.7915
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     385.0000    1652.0000
#     117.0000    263.0000
#   oddsratio: 0.5239
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 4019
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     591.0000    1446.0000
#     219.0000    161.0000
#   expected:
#     682.6520    1354.3480
#     127.3480    252.6520
#   chi2: 116.4360
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     591.0000    1446.0000
#     219.0000    161.0000
#   oddsratio: 0.3005
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 53081
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     513.0000    1524.0000
#     165.0000    215.0000
#   expected:
#     571.4050    1465.5950
#     106.5950    273.4050
#   chi2: 51.8751
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     513.0000    1524.0000
#     165.0000    215.0000
#   oddsratio: 0.4386
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 5849
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     265.0000    1772.0000
#     183.0000    197.0000
#   expected:
#     377.5656    1659.4344
#     70.4344    309.5656
#   chi2: 259.7025
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     265.0000    1772.0000
#     183.0000    197.0000
#   oddsratio: 0.1610
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: V1582
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     349.0000    1688.0000
#     154.0000    226.0000
#   expected:
#     423.9185    1613.0815
#     79.0815    300.9185
#   chi2: 104.9318
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     349.0000    1688.0000
#     154.0000    226.0000
#   oddsratio: 0.3034
#   pvalue: 0.0000
# done.

# %%
not_suspect_icd_code = list(set(df_ibd['icd_code'].unique().tolist()) - set(suspect_icd_codes))[:]

for not_suspect_icd_code in not_suspect_icd_code:
    print('--> Not Suspect ICD Code: {}'.format(not_suspect_icd_code))
    pvalue1 = construct_chi2_test(live_df, dead_df, not_suspect_icd_code, silent=True)
    pvalue2 = construct_fisher_test(live_df, dead_df, not_suspect_icd_code, silent=True)
    
    if pvalue1 <= 0.01 or pvalue2 <= 0.01:
        print('  chi2 test pvalue:\n    {:.8f}'.format(pvalue1))
        print('  fisher test pvalue:\n    {:.8f}'.format(pvalue2))
        
        pvalue1 = construct_chi2_test(live_df, dead_df, not_suspect_icd_code, silent=False)
        pvalue2 = construct_fisher_test(live_df, dead_df, not_suspect_icd_code, silent=False)
    
    # break
# Out:
# --> Not Suspect ICD Code: 24290
#   chi2 test pvalue:
#     0.00024471
#   fisher test pvalue:
#     0.00086980
# start chi2 test
#   observed:
#     5.0000    2032.0000
#     7.0000    373.0000
#   expected:
#     10.1134    2026.8866
#     1.8866    378.1134
#   chi2: 13.4522
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     5.0000    2032.0000
#     7.0000    373.0000
#   oddsratio: 0.1311
#   pvalue: 0.0009
# done.
# --> Not Suspect ICD Code: 43301
# --> Not Suspect ICD Code: M62838
# --> Not Suspect ICD Code: 42789
#   chi2 test pvalue:
#     0.00219393
#   fisher test pvalue:
#     0.00250836
# start chi2 test
#   observed:
#     157.0000    1880.0000
#     48.0000    332.0000
#   expected:
#     172.7700    1864.2300
#     32.2300    347.7700
#   chi2: 9.3798
#   pvalue: 0.0022
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     157.0000    1880.0000
#     48.0000    332.0000
#   oddsratio: 0.5776
#   pvalue: 0.0025
# done.
# --> Not Suspect ICD Code: E1136
# --> Not Suspect ICD Code: 73734
# --> Not Suspect ICD Code: 9998
# --> Not Suspect ICD Code: 24900
# --> Not Suspect ICD Code: R198
# --> Not Suspect ICD Code: 7019
# --> Not Suspect ICD Code: E739
# --> Not Suspect ICD Code: Y846
# --> Not Suspect ICD Code: G518
# --> Not Suspect ICD Code: M8088XD
# --> Not Suspect ICD Code: 5589
# --> Not Suspect ICD Code: 6182
# --> Not Suspect ICD Code: K740
# --> Not Suspect ICD Code: 5756
# --> Not Suspect ICD Code: 71846
# --> Not Suspect ICD Code: E8147
# --> Not Suspect ICD Code: O99612
# --> Not Suspect ICD Code: K614
# --> Not Suspect ICD Code: 40599
# --> Not Suspect ICD Code: V4364
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000002
# start chi2 test
#   observed:
#     41.0000    1996.0000
#     31.0000    349.0000
#   expected:
#     60.6802    1976.3198
#     11.3198    368.6802
#   chi2: 39.7453
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     41.0000    1996.0000
#     31.0000    349.0000
#   oddsratio: 0.2313
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 30151
# --> Not Suspect ICD Code: 71697
# --> Not Suspect ICD Code: 78607
# --> Not Suspect ICD Code: V8542
# --> Not Suspect ICD Code: R4181
# --> Not Suspect ICD Code: Y9229
# --> Not Suspect ICD Code: 28952
# --> Not Suspect ICD Code: M5030
# --> Not Suspect ICD Code: S81811A
# --> Not Suspect ICD Code: 2669
# --> Not Suspect ICD Code: 29640
# --> Not Suspect ICD Code: E9063
# --> Not Suspect ICD Code: Q870
# --> Not Suspect ICD Code: S2241XA
# --> Not Suspect ICD Code: 57149
# --> Not Suspect ICD Code: R29818
# --> Not Suspect ICD Code: J1100
# --> Not Suspect ICD Code: 20302
# --> Not Suspect ICD Code: M792
# --> Not Suspect ICD Code: V8543
# --> Not Suspect ICD Code: 73710
# --> Not Suspect ICD Code: M07649
# --> Not Suspect ICD Code: Y92199
# --> Not Suspect ICD Code: H532
# --> Not Suspect ICD Code: 5121
#   chi2 test pvalue:
#     0.00048630
#   fisher test pvalue:
#     0.00113552
# start chi2 test
#   observed:
#     10.0000    2027.0000
#     9.0000    371.0000
#   expected:
#     16.0128    2020.9872
#     2.9872    377.0128
#   chi2: 12.1675
#   pvalue: 0.0005
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2027.0000
#     9.0000    371.0000
#   oddsratio: 0.2034
#   pvalue: 0.0011
# done.
# --> Not Suspect ICD Code: J111
# --> Not Suspect ICD Code: 31239
# --> Not Suspect ICD Code: 28982
# --> Not Suspect ICD Code: 0785
# --> Not Suspect ICD Code: 71615
# --> Not Suspect ICD Code: G43829
# --> Not Suspect ICD Code: X12XXXA
# --> Not Suspect ICD Code: R591
# --> Not Suspect ICD Code: 65683
# --> Not Suspect ICD Code: 2710
# --> Not Suspect ICD Code: 99889
# --> Not Suspect ICD Code: 78639
# --> Not Suspect ICD Code: 4404
#   chi2 test pvalue:
#     0.00000351
#   fisher test pvalue:
#     0.00005150
# start chi2 test
#   observed:
#     5.0000    2032.0000
#     9.0000    371.0000
#   expected:
#     11.7989    2025.2011
#     2.2011    377.7989
#   chi2: 21.5133
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     5.0000    2032.0000
#     9.0000    371.0000
#   oddsratio: 0.1014
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: 59381
# --> Not Suspect ICD Code: 7842
# --> Not Suspect ICD Code: 28984
# --> Not Suspect ICD Code: F209
# --> Not Suspect ICD Code: N1339
# --> Not Suspect ICD Code: 6391
# --> Not Suspect ICD Code: Z91041
# --> Not Suspect ICD Code: 3159
# --> Not Suspect ICD Code: M797
# --> Not Suspect ICD Code: 96509
# --> Not Suspect ICD Code: 2798
# --> Not Suspect ICD Code: 73314
#   chi2 test pvalue:
#     0.00017842
#   fisher test pvalue:
#     0.00080072
# start chi2 test
#   observed:
#     3.0000    2034.0000
#     6.0000    374.0000
#   expected:
#     7.5850    2029.4150
#     1.4150    378.5850
#   chi2: 14.0458
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2034.0000
#     6.0000    374.0000
#   oddsratio: 0.0919
#   pvalue: 0.0008
# done.
# --> Not Suspect ICD Code: L02611
# --> Not Suspect ICD Code: H469
# --> Not Suspect ICD Code: E9390
# --> Not Suspect ICD Code: 71107
# --> Not Suspect ICD Code: F064
# --> Not Suspect ICD Code: 36107
# --> Not Suspect ICD Code: N471
# --> Not Suspect ICD Code: L400
# --> Not Suspect ICD Code: 44324
# --> Not Suspect ICD Code: B9629
# --> Not Suspect ICD Code: L97909
# --> Not Suspect ICD Code: E669
# --> Not Suspect ICD Code: I612
# --> Not Suspect ICD Code: 29660
# --> Not Suspect ICD Code: L89893
# --> Not Suspect ICD Code: 6079
# --> Not Suspect ICD Code: 4532
# --> Not Suspect ICD Code: 4552
# --> Not Suspect ICD Code: D702
# --> Not Suspect ICD Code: E9387
# --> Not Suspect ICD Code: E870
# --> Not Suspect ICD Code: V0990
# --> Not Suspect ICD Code: 99669
# --> Not Suspect ICD Code: 4941
# --> Not Suspect ICD Code: E9325
# --> Not Suspect ICD Code: E1051
# --> Not Suspect ICD Code: Z681
#   chi2 test pvalue:
#     0.00229677
#   fisher test pvalue:
#     0.00296973
# start chi2 test
#   observed:
#     18.0000    2019.0000
#     11.0000    369.0000
#   expected:
#     24.4406    2012.5594
#     4.5594    375.4406
#   chi2: 9.2958
#   pvalue: 0.0023
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     18.0000    2019.0000
#     11.0000    369.0000
#   oddsratio: 0.2991
#   pvalue: 0.0030
# done.
# --> Not Suspect ICD Code: 5559
# --> Not Suspect ICD Code: 53530
#   chi2 test pvalue:
#     0.00128577
#   fisher test pvalue:
#     0.00386033
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   expected:
#     2.5283    2034.4717
#     0.4717    379.5283
#   chi2: 10.3628
#   pvalue: 0.0013
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   oddsratio: 0.0000
#   pvalue: 0.0039
# done.
# --> Not Suspect ICD Code: I82623
# --> Not Suspect ICD Code: Z807
# --> Not Suspect ICD Code: 4940
#   chi2 test pvalue:
#     0.00007478
#   fisher test pvalue:
#     0.00041860
# start chi2 test
#   observed:
#     4.0000    2033.0000
#     7.0000    373.0000
#   expected:
#     9.2706    2027.7294
#     1.7294    378.2706
#   chi2: 15.6859
#   pvalue: 0.0001
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     4.0000    2033.0000
#     7.0000    373.0000
#   oddsratio: 0.1048
#   pvalue: 0.0004
# done.
# --> Not Suspect ICD Code: Z716
# --> Not Suspect ICD Code: D6862
# --> Not Suspect ICD Code: G500
# --> Not Suspect ICD Code: 41072
#   chi2 test pvalue:
#     0.00174811
#   fisher test pvalue:
#     0.00269383
# start chi2 test
#   observed:
#     12.0000    2025.0000
#     9.0000    371.0000
#   expected:
#     17.6984    2019.3016
#     3.3016    376.6984
#   chi2: 9.7968
#   pvalue: 0.0017
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     12.0000    2025.0000
#     9.0000    371.0000
#   oddsratio: 0.2443
#   pvalue: 0.0027
# done.
# --> Not Suspect ICD Code: 7503
# --> Not Suspect ICD Code: 65223
# --> Not Suspect ICD Code: 95919
# --> Not Suspect ICD Code: G9741
# --> Not Suspect ICD Code: T364X5A
# --> Not Suspect ICD Code: 29560
# --> Not Suspect ICD Code: 4918
# --> Not Suspect ICD Code: 20951
# --> Not Suspect ICD Code: E9435
# --> Not Suspect ICD Code: K3189
# --> Not Suspect ICD Code: V5427
# --> Not Suspect ICD Code: S61214A
# --> Not Suspect ICD Code: W108XXA
# --> Not Suspect ICD Code: 481
# --> Not Suspect ICD Code: Z6832
# --> Not Suspect ICD Code: 4731
# --> Not Suspect ICD Code: M3130
# --> Not Suspect ICD Code: T501X1A
# --> Not Suspect ICD Code: S62002A
# --> Not Suspect ICD Code: E1121
#   chi2 test pvalue:
#     0.00017842
#   fisher test pvalue:
#     0.00080072
# start chi2 test
#   observed:
#     3.0000    2034.0000
#     6.0000    374.0000
#   expected:
#     7.5850    2029.4150
#     1.4150    378.5850
#   chi2: 14.0458
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2034.0000
#     6.0000    374.0000
#   oddsratio: 0.0919
#   pvalue: 0.0008
# done.
# --> Not Suspect ICD Code: V4962
# --> Not Suspect ICD Code: F600
# --> Not Suspect ICD Code: O8612
# --> Not Suspect ICD Code: Z221
# --> Not Suspect ICD Code: 29189
# --> Not Suspect ICD Code: B9620
#   chi2 test pvalue:
#     0.00478841
#   fisher test pvalue:
#     0.00582460
# start chi2 test
#   observed:
#     36.0000    2001.0000
#     16.0000    364.0000
#   expected:
#     43.8246    1993.1754
#     8.1754    371.8246
#   chi2: 7.9577
#   pvalue: 0.0048
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     36.0000    2001.0000
#     16.0000    364.0000
#   oddsratio: 0.4093
#   pvalue: 0.0058
# done.
# --> Not Suspect ICD Code: M79A3
# --> Not Suspect ICD Code: M4854XA
# --> Not Suspect ICD Code: H409
# --> Not Suspect ICD Code: 70713
# --> Not Suspect ICD Code: 7514
# --> Not Suspect ICD Code: L89899
# --> Not Suspect ICD Code: 3668
# --> Not Suspect ICD Code: T8119XA
# --> Not Suspect ICD Code: I341
# --> Not Suspect ICD Code: K439
# --> Not Suspect ICD Code: K743
# --> Not Suspect ICD Code: M1A9XX0
# --> Not Suspect ICD Code: 2127
# --> Not Suspect ICD Code: M50022
# --> Not Suspect ICD Code: R1319
# --> Not Suspect ICD Code: 2753
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000002
# start chi2 test
#   observed:
#     61.0000    1976.0000
#     38.0000    342.0000
#   expected:
#     83.4353    1953.5647
#     15.5647    364.4353
#   chi2: 38.2465
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     61.0000    1976.0000
#     38.0000    342.0000
#   oddsratio: 0.2778
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 9752
# --> Not Suspect ICD Code: I83218
# --> Not Suspect ICD Code: 29212
# --> Not Suspect ICD Code: N3090
# --> Not Suspect ICD Code: Z1211
# --> Not Suspect ICD Code: N3941
# --> Not Suspect ICD Code: 29570
# --> Not Suspect ICD Code: 3549
# --> Not Suspect ICD Code: 1125
# --> Not Suspect ICD Code: Z3A00
# --> Not Suspect ICD Code: 67482
# --> Not Suspect ICD Code: 6809
# --> Not Suspect ICD Code: V2512
# --> Not Suspect ICD Code: M11279
# --> Not Suspect ICD Code: M19012
# --> Not Suspect ICD Code: R932
# --> Not Suspect ICD Code: 34280
# --> Not Suspect ICD Code: 28730
# --> Not Suspect ICD Code: 72611
# --> Not Suspect ICD Code: 4881
# --> Not Suspect ICD Code: 683
# --> Not Suspect ICD Code: L02422
# --> Not Suspect ICD Code: 1890
# --> Not Suspect ICD Code: T24312A
# --> Not Suspect ICD Code: 5570
#   chi2 test pvalue:
#     0.00237163
#   fisher test pvalue:
#     0.00292606
# start chi2 test
#   observed:
#     21.0000    2016.0000
#     12.0000    368.0000
#   expected:
#     27.8118    2009.1882
#     5.1882    374.8118
#   chi2: 9.2371
#   pvalue: 0.0024
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     21.0000    2016.0000
#     12.0000    368.0000
#   oddsratio: 0.3194
#   pvalue: 0.0029
# done.
# --> Not Suspect ICD Code: T373X6A
# --> Not Suspect ICD Code: 4270
# --> Not Suspect ICD Code: I82891
# --> Not Suspect ICD Code: 6202
# --> Not Suspect ICD Code: R3911
# --> Not Suspect ICD Code: K50818
# --> Not Suspect ICD Code: 37991
# --> Not Suspect ICD Code: 7299
# --> Not Suspect ICD Code: 0059
# --> Not Suspect ICD Code: M25512
# --> Not Suspect ICD Code: 30423
# --> Not Suspect ICD Code: 42822
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     28.0000    2009.0000
#     38.0000    342.0000
#   expected:
#     55.6235    1981.3765
#     10.3765    369.6235
#   chi2: 86.4869
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     28.0000    2009.0000
#     38.0000    342.0000
#   oddsratio: 0.1254
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: N261
# --> Not Suspect ICD Code: Q676
# --> Not Suspect ICD Code: Y733
# --> Not Suspect ICD Code: 3968
# --> Not Suspect ICD Code: 72706
# --> Not Suspect ICD Code: 29664
# --> Not Suspect ICD Code: E9347
# --> Not Suspect ICD Code: 8438
# --> Not Suspect ICD Code: 3080
# --> Not Suspect ICD Code: 53190
# --> Not Suspect ICD Code: 7249
# --> Not Suspect ICD Code: M25531
# --> Not Suspect ICD Code: F323
# --> Not Suspect ICD Code: 33385
# --> Not Suspect ICD Code: 34989
# --> Not Suspect ICD Code: I509
#   chi2 test pvalue:
#     0.00520609
#   fisher test pvalue:
#     0.00540173
# start chi2 test
#   observed:
#     20.0000    2017.0000
#     11.0000    369.0000
#   expected:
#     26.1262    2010.8738
#     4.8738    375.1262
#   chi2: 7.8064
#   pvalue: 0.0052
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     20.0000    2017.0000
#     11.0000    369.0000
#   oddsratio: 0.3326
#   pvalue: 0.0054
# done.
# --> Not Suspect ICD Code: 5932
# --> Not Suspect ICD Code: 0794
# --> Not Suspect ICD Code: 2728
# --> Not Suspect ICD Code: J392
# --> Not Suspect ICD Code: V441
#   chi2 test pvalue:
#     0.00018989
#   fisher test pvalue:
#     0.00056732
# start chi2 test
#   observed:
#     11.0000    2026.0000
#     10.0000    370.0000
#   expected:
#     17.6984    2019.3016
#     3.3016    376.6984
#   chi2: 13.9286
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     11.0000    2026.0000
#     10.0000    370.0000
#   oddsratio: 0.2009
#   pvalue: 0.0006
# done.
# --> Not Suspect ICD Code: 29650
# --> Not Suspect ICD Code: 452
# --> Not Suspect ICD Code: T8484XA
# --> Not Suspect ICD Code: E010
# --> Not Suspect ICD Code: C3490
#   chi2 test pvalue:
#     0.00007913
#   fisher test pvalue:
#     0.00060288
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     4.0000    376.0000
#   expected:
#     3.3711    2033.6289
#     0.6289    379.3711
#   chi2: 15.5791
#   pvalue: 0.0001
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     4.0000    376.0000
#   oddsratio: 0.0000
#   pvalue: 0.0006
# done.
# --> Not Suspect ICD Code: Z332
# --> Not Suspect ICD Code: K269
# --> Not Suspect ICD Code: C782
# --> Not Suspect ICD Code: G5770
# --> Not Suspect ICD Code: 30009
# --> Not Suspect ICD Code: V446
# --> Not Suspect ICD Code: 42682
#   chi2 test pvalue:
#     0.00084473
#   fisher test pvalue:
#     0.00263861
# start chi2 test
#   observed:
#     1.0000    2036.0000
#     4.0000    376.0000
#   expected:
#     4.2139    2032.7861
#     0.7861    379.2139
#   chi2: 11.1403
#   pvalue: 0.0008
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2036.0000
#     4.0000    376.0000
#   oddsratio: 0.0462
#   pvalue: 0.0026
# done.
# --> Not Suspect ICD Code: F4329
# --> Not Suspect ICD Code: M25451
# --> Not Suspect ICD Code: 64803
# --> Not Suspect ICD Code: 3371
# --> Not Suspect ICD Code: 2189
# --> Not Suspect ICD Code: I6782
# --> Not Suspect ICD Code: J8489
# --> Not Suspect ICD Code: T886XXA
# --> Not Suspect ICD Code: 45373
# --> Not Suspect ICD Code: 64783
# --> Not Suspect ICD Code: V1271
#   chi2 test pvalue:
#     0.00068692
#   fisher test pvalue:
#     0.00115003
# start chi2 test
#   observed:
#     21.0000    2016.0000
#     13.0000    367.0000
#   expected:
#     28.6545    2008.3455
#     5.3455    374.6545
#   chi2: 11.5243
#   pvalue: 0.0007
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     21.0000    2016.0000
#     13.0000    367.0000
#   oddsratio: 0.2941
#   pvalue: 0.0012
# done.
# --> Not Suspect ICD Code: 65621
# --> Not Suspect ICD Code: 28800
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     20.0000    2017.0000
#     24.0000    356.0000
#   expected:
#     37.0823    1999.9177
#     6.9177    373.0823
#   chi2: 48.0392
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     20.0000    2017.0000
#     24.0000    356.0000
#   oddsratio: 0.1471
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 2155
# --> Not Suspect ICD Code: 5952
# --> Not Suspect ICD Code: T8130XA
# --> Not Suspect ICD Code: 9093
# --> Not Suspect ICD Code: D72821
# --> Not Suspect ICD Code: 6271
# --> Not Suspect ICD Code: 4820
# --> Not Suspect ICD Code: S13161A
# --> Not Suspect ICD Code: M3481
# --> Not Suspect ICD Code: 7222
# --> Not Suspect ICD Code: L89300
# --> Not Suspect ICD Code: 1962
#   chi2 test pvalue:
#     0.00000062
#   fisher test pvalue:
#     0.00001417
# start chi2 test
#   observed:
#     7.0000    2030.0000
#     11.0000    369.0000
#   expected:
#     15.1700    2021.8300
#     2.8300    377.1700
#   chi2: 24.8513
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     7.0000    2030.0000
#     11.0000    369.0000
#   oddsratio: 0.1157
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 71536
#   chi2 test pvalue:
#     0.00000973
#   fisher test pvalue:
#     0.00004583
# start chi2 test
#   observed:
#     26.0000    2011.0000
#     18.0000    362.0000
#   expected:
#     37.0823    1999.9177
#     6.9177    373.0823
#   chi2: 19.5645
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     26.0000    2011.0000
#     18.0000    362.0000
#   oddsratio: 0.2600
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: S32512A
# --> Not Suspect ICD Code: 0479
# --> Not Suspect ICD Code: E8319
# --> Not Suspect ICD Code: V5416
# --> Not Suspect ICD Code: 42731
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     146.0000    1891.0000
#     122.0000    258.0000
#   expected:
#     225.8651    1811.1349
#     42.1349    337.8651
#   chi2: 199.5003
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     146.0000    1891.0000
#     122.0000    258.0000
#   oddsratio: 0.1633
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 78830
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000001
# start chi2 test
#   observed:
#     25.0000    2012.0000
#     25.0000    355.0000
#   expected:
#     42.1390    1994.8610
#     7.8610    372.1390
#   chi2: 42.6719
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     25.0000    2012.0000
#     25.0000    355.0000
#   oddsratio: 0.1764
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: A630
# --> Not Suspect ICD Code: 2639
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000001
# start chi2 test
#   observed:
#     101.0000    1936.0000
#     51.0000    329.0000
#   expected:
#     128.1026    1908.8974
#     23.8974    356.1026
#   chi2: 37.4966
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     101.0000    1936.0000
#     51.0000    329.0000
#   oddsratio: 0.3365
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: V5391
# --> Not Suspect ICD Code: K9403
# --> Not Suspect ICD Code: V167
# --> Not Suspect ICD Code: T39095A
# --> Not Suspect ICD Code: 60490
# --> Not Suspect ICD Code: 9160
# --> Not Suspect ICD Code: 0413
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000010
# start chi2 test
#   observed:
#     27.0000    2010.0000
#     24.0000    356.0000
#   expected:
#     42.9818    1994.0182
#     8.0182    371.9818
#   chi2: 36.2337
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     27.0000    2010.0000
#     24.0000    356.0000
#   oddsratio: 0.1993
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: N809
# --> Not Suspect ICD Code: 5982
# --> Not Suspect ICD Code: R310
# --> Not Suspect ICD Code: K859
# --> Not Suspect ICD Code: 24280
# --> Not Suspect ICD Code: I83228
# --> Not Suspect ICD Code: E861
#   chi2 test pvalue:
#     0.00772784
#   fisher test pvalue:
#     0.00784519
# start chi2 test
#   observed:
#     45.0000    1992.0000
#     18.0000    362.0000
#   expected:
#     53.0952    1983.9048
#     9.9048    370.0952
#   chi2: 7.0955
#   pvalue: 0.0077
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     45.0000    1992.0000
#     18.0000    362.0000
#   oddsratio: 0.4543
#   pvalue: 0.0078
# done.
# --> Not Suspect ICD Code: E1140
#   chi2 test pvalue:
#     0.00003429
#   fisher test pvalue:
#     0.00017220
# start chi2 test
#   observed:
#     11.0000    2026.0000
#     11.0000    369.0000
#   expected:
#     18.5412    2018.4588
#     3.4588    376.5412
#   chi2: 17.1639
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     11.0000    2026.0000
#     11.0000    369.0000
#   oddsratio: 0.1821
#   pvalue: 0.0002
# done.
# --> Not Suspect ICD Code: Z930
# --> Not Suspect ICD Code: Z01818
# --> Not Suspect ICD Code: K50013
# --> Not Suspect ICD Code: J9811
# --> Not Suspect ICD Code: 2448
# --> Not Suspect ICD Code: 4378
# --> Not Suspect ICD Code: 7991
# --> Not Suspect ICD Code: Z48815
# --> Not Suspect ICD Code: R040
# --> Not Suspect ICD Code: E9179
# --> Not Suspect ICD Code: K912
# --> Not Suspect ICD Code: 6959
# --> Not Suspect ICD Code: L02414
# --> Not Suspect ICD Code: 2312
# --> Not Suspect ICD Code: 20070
# --> Not Suspect ICD Code: V444
# --> Not Suspect ICD Code: T84226A
# --> Not Suspect ICD Code: J351
# --> Not Suspect ICD Code: I952
# --> Not Suspect ICD Code: 30928
# --> Not Suspect ICD Code: G4739
# --> Not Suspect ICD Code: R339
# --> Not Suspect ICD Code: T45515A
# --> Not Suspect ICD Code: 7366
# --> Not Suspect ICD Code: Z9350
# --> Not Suspect ICD Code: D61818
#   chi2 test pvalue:
#     0.00124772
#   fisher test pvalue:
#     0.00227994
# start chi2 test
#   observed:
#     9.0000    2028.0000
#     8.0000    372.0000
#   expected:
#     14.3273    2022.6727
#     2.6727    377.3273
#   chi2: 10.4183
#   pvalue: 0.0012
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     9.0000    2028.0000
#     8.0000    372.0000
#   oddsratio: 0.2064
#   pvalue: 0.0023
# done.
# --> Not Suspect ICD Code: F6081
# --> Not Suspect ICD Code: 99641
# --> Not Suspect ICD Code: T400X6A
# --> Not Suspect ICD Code: D471
# --> Not Suspect ICD Code: F54
# --> Not Suspect ICD Code: E9353
# --> Not Suspect ICD Code: L02612
# --> Not Suspect ICD Code: 41061
# --> Not Suspect ICD Code: V4985
# --> Not Suspect ICD Code: 72671
# --> Not Suspect ICD Code: E8781
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000001
# start chi2 test
#   observed:
#     27.0000    2010.0000
#     26.0000    354.0000
#   expected:
#     44.6674    1992.3326
#     8.3326    371.6674
#   chi2: 42.9081
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     27.0000    2010.0000
#     26.0000    354.0000
#   oddsratio: 0.1829
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 1571
#   chi2 test pvalue:
#     0.00128577
#   fisher test pvalue:
#     0.00386033
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   expected:
#     2.5283    2034.4717
#     0.4717    379.5283
#   chi2: 10.3628
#   pvalue: 0.0013
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   oddsratio: 0.0000
#   pvalue: 0.0039
# done.
# --> Not Suspect ICD Code: M7061
# --> Not Suspect ICD Code: H538
# --> Not Suspect ICD Code: 73341
# --> Not Suspect ICD Code: I6529
# --> Not Suspect ICD Code: 53200
# --> Not Suspect ICD Code: Z9181
#   chi2 test pvalue:
#     0.00002314
#   fisher test pvalue:
#     0.00008795
# start chi2 test
#   observed:
#     25.0000    2012.0000
#     17.0000    363.0000
#   expected:
#     35.3968    2001.6032
#     6.6032    373.3968
#   chi2: 17.9114
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     25.0000    2012.0000
#     17.0000    363.0000
#   oddsratio: 0.2653
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: S7011XA
# --> Not Suspect ICD Code: 6398
# --> Not Suspect ICD Code: 7921
# --> Not Suspect ICD Code: Z6836
# --> Not Suspect ICD Code: 45384
# --> Not Suspect ICD Code: O658
# --> Not Suspect ICD Code: 78652
# --> Not Suspect ICD Code: K760
# --> Not Suspect ICD Code: I69151
# --> Not Suspect ICD Code: V151
# --> Not Suspect ICD Code: V1209
# --> Not Suspect ICD Code: L97418
# --> Not Suspect ICD Code: K7689
# --> Not Suspect ICD Code: Z952
# --> Not Suspect ICD Code: 83100
# --> Not Suspect ICD Code: R402362
# --> Not Suspect ICD Code: E9344
# --> Not Suspect ICD Code: S01111A
# --> Not Suspect ICD Code: 44381
#   chi2 test pvalue:
#     0.00409202
#   fisher test pvalue:
#     0.00693459
# start chi2 test
#   observed:
#     2.0000    2035.0000
#     4.0000    376.0000
#   expected:
#     5.0567    2031.9433
#     0.9433    379.0567
#   chi2: 8.2425
#   pvalue: 0.0041
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2035.0000
#     4.0000    376.0000
#   oddsratio: 0.0924
#   pvalue: 0.0069
# done.
# --> Not Suspect ICD Code: I82611
# --> Not Suspect ICD Code: D1432
# --> Not Suspect ICD Code: 4557
# --> Not Suspect ICD Code: T8612
# --> Not Suspect ICD Code: 8500
# --> Not Suspect ICD Code: 38812
# --> Not Suspect ICD Code: 2861
# --> Not Suspect ICD Code: D126
# --> Not Suspect ICD Code: 53783
# --> Not Suspect ICD Code: Z8551
#   chi2 test pvalue:
#     0.00465005
#   fisher test pvalue:
#     0.00681917
# start chi2 test
#   observed:
#     4.0000    2033.0000
#     5.0000    375.0000
#   expected:
#     7.5850    2029.4150
#     1.4150    378.5850
#   chi2: 8.0107
#   pvalue: 0.0047
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     4.0000    2033.0000
#     5.0000    375.0000
#   oddsratio: 0.1476
#   pvalue: 0.0068
# done.
# --> Not Suspect ICD Code: M459
# --> Not Suspect ICD Code: 36645
# --> Not Suspect ICD Code: Z8614
# --> Not Suspect ICD Code: 28731
# --> Not Suspect ICD Code: 73005
# --> Not Suspect ICD Code: 78459
# --> Not Suspect ICD Code: R8299
# --> Not Suspect ICD Code: 6192
# --> Not Suspect ICD Code: 2900
# --> Not Suspect ICD Code: 9009
# --> Not Suspect ICD Code: 56889
# --> Not Suspect ICD Code: I69351
# --> Not Suspect ICD Code: Y92009
# --> Not Suspect ICD Code: I082
# --> Not Suspect ICD Code: 04109
# --> Not Suspect ICD Code: R197
# --> Not Suspect ICD Code: 53510
# --> Not Suspect ICD Code: 4588
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000003
# start chi2 test
#   observed:
#     10.0000    2027.0000
#     17.0000    363.0000
#   expected:
#     22.7551    2014.2449
#     4.2449    375.7551
#   chi2: 42.4546
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2027.0000
#     17.0000    363.0000
#   oddsratio: 0.1053
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: N630
# --> Not Suspect ICD Code: 55092
# --> Not Suspect ICD Code: 5566
#   chi2 test pvalue:
#     0.00017372
#   fisher test pvalue:
#     0.00026235
# start chi2 test
#   observed:
#     124.0000    1913.0000
#     44.0000    336.0000
#   expected:
#     141.5871    1895.4129
#     26.4129    353.5871
#   chi2: 14.0959
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     124.0000    1913.0000
#     44.0000    336.0000
#   oddsratio: 0.4950
#   pvalue: 0.0003
# done.
# --> Not Suspect ICD Code: 6170
# --> Not Suspect ICD Code: C801
# --> Not Suspect ICD Code: 46611
# --> Not Suspect ICD Code: V1254
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     56.0000    1981.0000
#     42.0000    338.0000
#   expected:
#     82.5925    1954.4075
#     15.4075    364.5925
#   chi2: 54.6461
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     56.0000    1981.0000
#     42.0000    338.0000
#   oddsratio: 0.2275
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 2899
# --> Not Suspect ICD Code: 28521
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     22.0000    2015.0000
#     55.0000    325.0000
#   expected:
#     64.8941    1972.1059
#     12.1059    367.8941
#   chi2: 181.9530
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     22.0000    2015.0000
#     55.0000    325.0000
#   oddsratio: 0.0645
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: D649
#   chi2 test pvalue:
#     0.00000010
#   fisher test pvalue:
#     0.00000062
# start chi2 test
#   observed:
#     96.0000    1941.0000
#     45.0000    335.0000
#   expected:
#     118.8320    1918.1680
#     22.1680    357.8320
#   chi2: 28.3478
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     96.0000    1941.0000
#     45.0000    335.0000
#   oddsratio: 0.3682
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: R5383
# --> Not Suspect ICD Code: L309
# --> Not Suspect ICD Code: 5568
# --> Not Suspect ICD Code: V1047
# --> Not Suspect ICD Code: Z8049
# --> Not Suspect ICD Code: L97421
# --> Not Suspect ICD Code: 36410
# --> Not Suspect ICD Code: 24200
# --> Not Suspect ICD Code: F0151
# --> Not Suspect ICD Code: D869
# --> Not Suspect ICD Code: 2114
# --> Not Suspect ICD Code: 92410
# --> Not Suspect ICD Code: M19041
# --> Not Suspect ICD Code: T826XXA
# --> Not Suspect ICD Code: 7515
# --> Not Suspect ICD Code: 3556
# --> Not Suspect ICD Code: 34541
# --> Not Suspect ICD Code: 4549
# --> Not Suspect ICD Code: Z3A19
# --> Not Suspect ICD Code: Z9884
# --> Not Suspect ICD Code: 4489
# --> Not Suspect ICD Code: 99941
# --> Not Suspect ICD Code: 60783
# --> Not Suspect ICD Code: 80625
# --> Not Suspect ICD Code: V568
# --> Not Suspect ICD Code: 8442
# --> Not Suspect ICD Code: 73390
# --> Not Suspect ICD Code: 7295
#   chi2 test pvalue:
#     0.00254904
#   fisher test pvalue:
#     0.00288587
# start chi2 test
#   observed:
#     51.0000    1986.0000
#     21.0000    359.0000
#   expected:
#     60.6802    1976.3198
#     11.3198    368.6802
#   chi2: 9.1051
#   pvalue: 0.0025
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     51.0000    1986.0000
#     21.0000    359.0000
#   oddsratio: 0.4390
#   pvalue: 0.0029
# done.
# --> Not Suspect ICD Code: K9182
# --> Not Suspect ICD Code: M96843
# --> Not Suspect ICD Code: E8495
# --> Not Suspect ICD Code: 20283
# --> Not Suspect ICD Code: K9411
# --> Not Suspect ICD Code: E8498
# --> Not Suspect ICD Code: K209
# --> Not Suspect ICD Code: 45351
# --> Not Suspect ICD Code: Z8674
# --> Not Suspect ICD Code: 99689
# --> Not Suspect ICD Code: I76
# --> Not Suspect ICD Code: 7873
# --> Not Suspect ICD Code: V5865
# --> Not Suspect ICD Code: R441
# --> Not Suspect ICD Code: 03843
# --> Not Suspect ICD Code: V1819
# --> Not Suspect ICD Code: 34201
# --> Not Suspect ICD Code: 7242
# --> Not Suspect ICD Code: 4465
# --> Not Suspect ICD Code: H00016
# --> Not Suspect ICD Code: F19980
# --> Not Suspect ICD Code: 6141
# --> Not Suspect ICD Code: F39
# --> Not Suspect ICD Code: 3575
# --> Not Suspect ICD Code: O9962
# --> Not Suspect ICD Code: Z9079
# --> Not Suspect ICD Code: 2550
# --> Not Suspect ICD Code: N451
# --> Not Suspect ICD Code: Z96653
# --> Not Suspect ICD Code: E530
# --> Not Suspect ICD Code: D89811
# --> Not Suspect ICD Code: 6268
# --> Not Suspect ICD Code: 05443
# --> Not Suspect ICD Code: R233
# --> Not Suspect ICD Code: 29623
# --> Not Suspect ICD Code: 66551
# --> Not Suspect ICD Code: R0982
# --> Not Suspect ICD Code: 99639
# --> Not Suspect ICD Code: F1910
# --> Not Suspect ICD Code: R12
# --> Not Suspect ICD Code: 9070
# --> Not Suspect ICD Code: E854
# --> Not Suspect ICD Code: 81503
# --> Not Suspect ICD Code: Z853
# --> Not Suspect ICD Code: V8699XA
# --> Not Suspect ICD Code: 59010
#   chi2 test pvalue:
#     0.00022851
#   fisher test pvalue:
#     0.00069242
# start chi2 test
#   observed:
#     9.0000    2028.0000
#     9.0000    371.0000
#   expected:
#     15.1700    2021.8300
#     2.8300    377.1700
#   chi2: 13.5808
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     9.0000    2028.0000
#     9.0000    371.0000
#   oddsratio: 0.1829
#   pvalue: 0.0007
# done.
# --> Not Suspect ICD Code: 3693
# --> Not Suspect ICD Code: 5118
# --> Not Suspect ICD Code: 7856
#   chi2 test pvalue:
#     0.00004593
#   fisher test pvalue:
#     0.00012882
# start chi2 test
#   observed:
#     32.0000    2005.0000
#     19.0000    361.0000
#   expected:
#     42.9818    1994.0182
#     8.0182    371.9818
#   chi2: 16.6089
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     32.0000    2005.0000
#     19.0000    361.0000
#   oddsratio: 0.3032
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: V8401
# --> Not Suspect ICD Code: 53784
# --> Not Suspect ICD Code: Z9861
# --> Not Suspect ICD Code: H8110
# --> Not Suspect ICD Code: 01890
# --> Not Suspect ICD Code: N3281
# --> Not Suspect ICD Code: 2825
# --> Not Suspect ICD Code: M5033
# --> Not Suspect ICD Code: V552
# --> Not Suspect ICD Code: 64244
# --> Not Suspect ICD Code: M5080
# --> Not Suspect ICD Code: T82534A
# --> Not Suspect ICD Code: 34510
# --> Not Suspect ICD Code: 57451
# --> Not Suspect ICD Code: 5277
# --> Not Suspect ICD Code: Y92019
# --> Not Suspect ICD Code: Y92129
# --> Not Suspect ICD Code: 8750
# --> Not Suspect ICD Code: V1087
# --> Not Suspect ICD Code: I629
# --> Not Suspect ICD Code: K580
# --> Not Suspect ICD Code: Z90710
# --> Not Suspect ICD Code: V5481
# --> Not Suspect ICD Code: Z85118
#   chi2 test pvalue:
#     0.00024471
#   fisher test pvalue:
#     0.00086980
# start chi2 test
#   observed:
#     5.0000    2032.0000
#     7.0000    373.0000
#   expected:
#     10.1134    2026.8866
#     1.8866    378.1134
#   chi2: 13.4522
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     5.0000    2032.0000
#     7.0000    373.0000
#   oddsratio: 0.1311
#   pvalue: 0.0009
# done.
# --> Not Suspect ICD Code: 7942
# --> Not Suspect ICD Code: F1120
# --> Not Suspect ICD Code: D124
# --> Not Suspect ICD Code: N410
# --> Not Suspect ICD Code: 7509
# --> Not Suspect ICD Code: T7849XA
# --> Not Suspect ICD Code: D47Z1
# --> Not Suspect ICD Code: 5723
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000002
# start chi2 test
#   observed:
#     28.0000    2009.0000
#     26.0000    354.0000
#   expected:
#     45.5101    1991.4899
#     8.4899    371.5101
#   chi2: 41.3631
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     28.0000    2009.0000
#     26.0000    354.0000
#   oddsratio: 0.1898
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 5968
# --> Not Suspect ICD Code: Z87442
# --> Not Suspect ICD Code: 79981
# --> Not Suspect ICD Code: V173
#   chi2 test pvalue:
#     0.00033574
#   fisher test pvalue:
#     0.00083452
# start chi2 test
#   observed:
#     31.0000    2006.0000
#     17.0000    363.0000
#   expected:
#     40.4535    1996.5465
#     7.5465    372.4535
#   chi2: 12.8597
#   pvalue: 0.0003
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     31.0000    2006.0000
#     17.0000    363.0000
#   oddsratio: 0.3300
#   pvalue: 0.0008
# done.
# --> Not Suspect ICD Code: R312
# --> Not Suspect ICD Code: 1536
# --> Not Suspect ICD Code: Y835
# --> Not Suspect ICD Code: V4586
# --> Not Suspect ICD Code: E8494
# --> Not Suspect ICD Code: K922
#   chi2 test pvalue:
#     0.00048630
#   fisher test pvalue:
#     0.00113552
# start chi2 test
#   observed:
#     10.0000    2027.0000
#     9.0000    371.0000
#   expected:
#     16.0128    2020.9872
#     2.9872    377.0128
#   chi2: 12.1675
#   pvalue: 0.0005
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2027.0000
#     9.0000    371.0000
#   oddsratio: 0.2034
#   pvalue: 0.0011
# done.
# --> Not Suspect ICD Code: V072
# --> Not Suspect ICD Code: 57421
# --> Not Suspect ICD Code: 9221
# --> Not Suspect ICD Code: 30181
# --> Not Suspect ICD Code: K640
# --> Not Suspect ICD Code: F10288
# --> Not Suspect ICD Code: M86151
# --> Not Suspect ICD Code: R008
# --> Not Suspect ICD Code: E031
# --> Not Suspect ICD Code: 7051
# --> Not Suspect ICD Code: 84200
# --> Not Suspect ICD Code: M25562
# --> Not Suspect ICD Code: 5679
# --> Not Suspect ICD Code: 72740
# --> Not Suspect ICD Code: Y92008
# --> Not Suspect ICD Code: 8470
# --> Not Suspect ICD Code: L97524
# --> Not Suspect ICD Code: E038
# --> Not Suspect ICD Code: N83202
# --> Not Suspect ICD Code: 9051
# --> Not Suspect ICD Code: F429
# --> Not Suspect ICD Code: 5941
# --> Not Suspect ICD Code: E610
# --> Not Suspect ICD Code: L500
# --> Not Suspect ICD Code: V6403
# --> Not Suspect ICD Code: L258
# --> Not Suspect ICD Code: I493
# --> Not Suspect ICD Code: I69359
# --> Not Suspect ICD Code: 700
# --> Not Suspect ICD Code: O9081
# --> Not Suspect ICD Code: 29284
# --> Not Suspect ICD Code: 57481
# --> Not Suspect ICD Code: 566
# --> Not Suspect ICD Code: 1542
# --> Not Suspect ICD Code: 71239
# --> Not Suspect ICD Code: 5239
# --> Not Suspect ICD Code: 99791
# --> Not Suspect ICD Code: K259
# --> Not Suspect ICD Code: 78449
# --> Not Suspect ICD Code: 30750
# --> Not Suspect ICD Code: C7802
# --> Not Suspect ICD Code: 2979
# --> Not Suspect ICD Code: 74346
# --> Not Suspect ICD Code: Z89422
# --> Not Suspect ICD Code: 6018
# --> Not Suspect ICD Code: 7241
# --> Not Suspect ICD Code: 71535
#   chi2 test pvalue:
#     0.00772499
#   fisher test pvalue:
#     0.00773142
# start chi2 test
#   observed:
#     15.0000    2022.0000
#     9.0000    371.0000
#   expected:
#     20.2267    2016.7733
#     3.7733    376.2267
#   chi2: 7.0961
#   pvalue: 0.0077
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     15.0000    2022.0000
#     9.0000    371.0000
#   oddsratio: 0.3058
#   pvalue: 0.0077
# done.
# --> Not Suspect ICD Code: 20280
# --> Not Suspect ICD Code: 4271
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000002
# start chi2 test
#   observed:
#     19.0000    2018.0000
#     22.0000    358.0000
#   expected:
#     34.5540    2002.4460
#     6.4460    373.5540
#   chi2: 42.4354
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     19.0000    2018.0000
#     22.0000    358.0000
#   oddsratio: 0.1532
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 81000
# --> Not Suspect ICD Code: C50411
# --> Not Suspect ICD Code: 78079
#   chi2 test pvalue:
#     0.00000002
#   fisher test pvalue:
#     0.00000032
# start chi2 test
#   observed:
#     46.0000    1991.0000
#     30.0000    350.0000
#   expected:
#     64.0513    1972.9487
#     11.9487    368.0513
#   chi2: 31.5834
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     46.0000    1991.0000
#     30.0000    350.0000
#   oddsratio: 0.2695
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 45621
#   chi2 test pvalue:
#     0.00000733
#   fisher test pvalue:
#     0.00004604
# start chi2 test
#   observed:
#     18.0000    2019.0000
#     15.0000    365.0000
#   expected:
#     27.8118    2009.1882
#     5.1882    374.8118
#   chi2: 20.1047
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     18.0000    2019.0000
#     15.0000    365.0000
#   oddsratio: 0.2169
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: J90
#   chi2 test pvalue:
#     0.00001457
#   fisher test pvalue:
#     0.00011001
# start chi2 test
#   observed:
#     8.0000    2029.0000
#     10.0000    370.0000
#   expected:
#     15.1700    2021.8300
#     2.8300    377.1700
#   chi2: 18.7936
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     8.0000    2029.0000
#     10.0000    370.0000
#   oddsratio: 0.1459
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: B952
#   chi2 test pvalue:
#     0.00048630
#   fisher test pvalue:
#     0.00113552
# start chi2 test
#   observed:
#     10.0000    2027.0000
#     9.0000    371.0000
#   expected:
#     16.0128    2020.9872
#     2.9872    377.0128
#   chi2: 12.1675
#   pvalue: 0.0005
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2027.0000
#     9.0000    371.0000
#   oddsratio: 0.2034
#   pvalue: 0.0011
# done.
# --> Not Suspect ICD Code: N7011
# --> Not Suspect ICD Code: D7582
# --> Not Suspect ICD Code: 4139
# --> Not Suspect ICD Code: Z7682
# --> Not Suspect ICD Code: V8534
# --> Not Suspect ICD Code: V5864
#   chi2 test pvalue:
#     0.00028523
#   fisher test pvalue:
#     0.00069442
# start chi2 test
#   observed:
#     14.0000    2023.0000
#     11.0000    369.0000
#   expected:
#     21.0695    2015.9305
#     3.9305    376.0695
#   chi2: 13.1650
#   pvalue: 0.0003
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     14.0000    2023.0000
#     11.0000    369.0000
#   oddsratio: 0.2321
#   pvalue: 0.0007
# done.
# --> Not Suspect ICD Code: M26609
# --> Not Suspect ICD Code: V1529
# --> Not Suspect ICD Code: I209
# --> Not Suspect ICD Code: L97209
# --> Not Suspect ICD Code: K91858
# --> Not Suspect ICD Code: D531
# --> Not Suspect ICD Code: 75319
# --> Not Suspect ICD Code: 56942
# --> Not Suspect ICD Code: E1144
# --> Not Suspect ICD Code: K433
# --> Not Suspect ICD Code: 1966
# --> Not Suspect ICD Code: 35781
# --> Not Suspect ICD Code: H8120
# --> Not Suspect ICD Code: 78869
# --> Not Suspect ICD Code: K838
# --> Not Suspect ICD Code: 99632
# --> Not Suspect ICD Code: V4361
# --> Not Suspect ICD Code: R440
# --> Not Suspect ICD Code: 41070
# --> Not Suspect ICD Code: I5023
# --> Not Suspect ICD Code: L97911
# --> Not Suspect ICD Code: N730
# --> Not Suspect ICD Code: E9309
# --> Not Suspect ICD Code: 72789
# --> Not Suspect ICD Code: 0390
# --> Not Suspect ICD Code: C251
#   chi2 test pvalue:
#     0.00128577
#   fisher test pvalue:
#     0.00386033
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   expected:
#     2.5283    2034.4717
#     0.4717    379.5283
#   chi2: 10.3628
#   pvalue: 0.0013
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   oddsratio: 0.0000
#   pvalue: 0.0039
# done.
# --> Not Suspect ICD Code: Y908
# --> Not Suspect ICD Code: 25071
#   chi2 test pvalue:
#     0.00128577
#   fisher test pvalue:
#     0.00386033
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   expected:
#     2.5283    2034.4717
#     0.4717    379.5283
#   chi2: 10.3628
#   pvalue: 0.0013
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   oddsratio: 0.0000
#   pvalue: 0.0039
# done.
# --> Not Suspect ICD Code: 75683
# --> Not Suspect ICD Code: O7589
# --> Not Suspect ICD Code: N040
# --> Not Suspect ICD Code: J910
# --> Not Suspect ICD Code: J4540
# --> Not Suspect ICD Code: N610
# --> Not Suspect ICD Code: 20921
# --> Not Suspect ICD Code: K50913
# --> Not Suspect ICD Code: 53649
# --> Not Suspect ICD Code: 24220
# --> Not Suspect ICD Code: V2511
# --> Not Suspect ICD Code: K7210
# --> Not Suspect ICD Code: R296
# --> Not Suspect ICD Code: 2763
#   chi2 test pvalue:
#     0.00072156
#   fisher test pvalue:
#     0.00141639
# start chi2 test
#   observed:
#     30.0000    2007.0000
#     16.0000    364.0000
#   expected:
#     38.7679    1998.2321
#     7.2321    372.7679
#   chi2: 11.4329
#   pvalue: 0.0007
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     30.0000    2007.0000
#     16.0000    364.0000
#   oddsratio: 0.3401
#   pvalue: 0.0014
# done.
# --> Not Suspect ICD Code: 3019
# --> Not Suspect ICD Code: Z043
# --> Not Suspect ICD Code: 1129
# --> Not Suspect ICD Code: 138
# --> Not Suspect ICD Code: I82491
# --> Not Suspect ICD Code: 4412
# --> Not Suspect ICD Code: 25080
#   chi2 test pvalue:
#     0.00000002
#   fisher test pvalue:
#     0.00000100
# start chi2 test
#   observed:
#     11.0000    2026.0000
#     15.0000    365.0000
#   expected:
#     21.9123    2015.0877
#     4.0877    375.9123
#   chi2: 31.8123
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     11.0000    2026.0000
#     15.0000    365.0000
#   oddsratio: 0.1321
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: N141
# --> Not Suspect ICD Code: I878
# --> Not Suspect ICD Code: 1958
# --> Not Suspect ICD Code: 57420
# --> Not Suspect ICD Code: A049
# --> Not Suspect ICD Code: 4379
# --> Not Suspect ICD Code: 44101
# --> Not Suspect ICD Code: O3411
# --> Not Suspect ICD Code: K9189
# --> Not Suspect ICD Code: V1507
# --> Not Suspect ICD Code: V5842
# --> Not Suspect ICD Code: V0981
# --> Not Suspect ICD Code: T400X5A
# --> Not Suspect ICD Code: I7101
# --> Not Suspect ICD Code: K8070
# --> Not Suspect ICD Code: 5713
# --> Not Suspect ICD Code: 65491
# --> Not Suspect ICD Code: 78605
# --> Not Suspect ICD Code: 41402
#   chi2 test pvalue:
#     0.00001242
#   fisher test pvalue:
#     0.00011102
# start chi2 test
#   observed:
#     6.0000    2031.0000
#     9.0000    371.0000
#   expected:
#     12.6417    2024.3583
#     2.3583    377.6417
#   chi2: 19.0972
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     6.0000    2031.0000
#     9.0000    371.0000
#   oddsratio: 0.1218
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: 4720
# --> Not Suspect ICD Code: S0081XA
# --> Not Suspect ICD Code: R4189
# --> Not Suspect ICD Code: J189
#   chi2 test pvalue:
#     0.00000017
#   fisher test pvalue:
#     0.00000160
# start chi2 test
#   observed:
#     45.0000    1992.0000
#     28.0000    352.0000
#   expected:
#     61.5230    1975.4770
#     11.4770    368.5230
#   chi2: 27.3691
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     45.0000    1992.0000
#     28.0000    352.0000
#   oddsratio: 0.2840
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 41513
# --> Not Suspect ICD Code: 5275
# --> Not Suspect ICD Code: R290
# --> Not Suspect ICD Code: 66411
# --> Not Suspect ICD Code: V440
# --> Not Suspect ICD Code: 33920
# --> Not Suspect ICD Code: R6884
# --> Not Suspect ICD Code: V5489
# --> Not Suspect ICD Code: Z3A33
# --> Not Suspect ICD Code: E1165
#   chi2 test pvalue:
#     0.00001837
#   fisher test pvalue:
#     0.00009077
# start chi2 test
#   observed:
#     17.0000    2020.0000
#     14.0000    366.0000
#   expected:
#     26.1262    2010.8738
#     4.8738    375.1262
#   chi2: 18.3511
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     17.0000    2020.0000
#     14.0000    366.0000
#   oddsratio: 0.2200
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: M4806
# --> Not Suspect ICD Code: 7101
# --> Not Suspect ICD Code: M84559A
# --> Not Suspect ICD Code: 35801
# --> Not Suspect ICD Code: E9670
# --> Not Suspect ICD Code: 5851
# --> Not Suspect ICD Code: Z954
# --> Not Suspect ICD Code: J1000
# --> Not Suspect ICD Code: 486
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     126.0000    1911.0000
#     99.0000    281.0000
#   expected:
#     189.6256    1847.3744
#     35.3744    344.6256
#   chi2: 147.3815
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     126.0000    1911.0000
#     99.0000    281.0000
#   oddsratio: 0.1871
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: T80219A
# --> Not Suspect ICD Code: T508X5A
# --> Not Suspect ICD Code: 78841
# --> Not Suspect ICD Code: 20600
# --> Not Suspect ICD Code: V556
# --> Not Suspect ICD Code: 4162
#   chi2 test pvalue:
#     0.00001788
#   fisher test pvalue:
#     0.00017588
# start chi2 test
#   observed:
#     3.0000    2034.0000
#     7.0000    373.0000
#   expected:
#     8.4278    2028.5722
#     1.5722    378.4278
#   chi2: 18.4029
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2034.0000
#     7.0000    373.0000
#   oddsratio: 0.0786
#   pvalue: 0.0002
# done.
# --> Not Suspect ICD Code: T404X5A
# --> Not Suspect ICD Code: V641
# --> Not Suspect ICD Code: 1950
# --> Not Suspect ICD Code: Q6101
# --> Not Suspect ICD Code: T879
# --> Not Suspect ICD Code: 30390
#   chi2 test pvalue:
#     0.00018342
#   fisher test pvalue:
#     0.00043272
# start chi2 test
#   observed:
#     21.0000    2016.0000
#     14.0000    366.0000
#   expected:
#     29.4973    2007.5027
#     5.5027    374.4973
#   chi2: 13.9937
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     21.0000    2016.0000
#     14.0000    366.0000
#   oddsratio: 0.2723
#   pvalue: 0.0004
# done.
# --> Not Suspect ICD Code: V5401
# --> Not Suspect ICD Code: I5089
# --> Not Suspect ICD Code: K822
# --> Not Suspect ICD Code: 47829
# --> Not Suspect ICD Code: 65921
# --> Not Suspect ICD Code: 00869
# --> Not Suspect ICD Code: 86803
# --> Not Suspect ICD Code: K449
# --> Not Suspect ICD Code: 4572
# --> Not Suspect ICD Code: K521
# --> Not Suspect ICD Code: E9319
#   chi2 test pvalue:
#     0.00001788
#   fisher test pvalue:
#     0.00017588
# start chi2 test
#   observed:
#     3.0000    2034.0000
#     7.0000    373.0000
#   expected:
#     8.4278    2028.5722
#     1.5722    378.4278
#   chi2: 18.4029
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2034.0000
#     7.0000    373.0000
#   oddsratio: 0.0786
#   pvalue: 0.0002
# done.
# --> Not Suspect ICD Code: 49122
#   chi2 test pvalue:
#     0.00409202
#   fisher test pvalue:
#     0.00693459
# start chi2 test
#   observed:
#     2.0000    2035.0000
#     4.0000    376.0000
#   expected:
#     5.0567    2031.9433
#     0.9433    379.0567
#   chi2: 8.2425
#   pvalue: 0.0041
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2035.0000
#     4.0000    376.0000
#   oddsratio: 0.0924
#   pvalue: 0.0069
# done.
# --> Not Suspect ICD Code: E8192
# --> Not Suspect ICD Code: 920
#   chi2 test pvalue:
#     0.00320912
#   fisher test pvalue:
#     0.00459702
# start chi2 test
#   observed:
#     8.0000    2029.0000
#     7.0000    373.0000
#   expected:
#     12.6417    2024.3583
#     2.3583    377.6417
#   chi2: 8.6846
#   pvalue: 0.0032
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     8.0000    2029.0000
#     7.0000    373.0000
#   oddsratio: 0.2101
#   pvalue: 0.0046
# done.
# --> Not Suspect ICD Code: K745
# --> Not Suspect ICD Code: N411
# --> Not Suspect ICD Code: E8504
# --> Not Suspect ICD Code: 33941
# --> Not Suspect ICD Code: E860
# --> Not Suspect ICD Code: 81201
# --> Not Suspect ICD Code: 59789
# --> Not Suspect ICD Code: 72887
#   chi2 test pvalue:
#     0.00022851
#   fisher test pvalue:
#     0.00069242
# start chi2 test
#   observed:
#     9.0000    2028.0000
#     9.0000    371.0000
#   expected:
#     15.1700    2021.8300
#     2.8300    377.1700
#   chi2: 13.5808
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     9.0000    2028.0000
#     9.0000    371.0000
#   oddsratio: 0.1829
#   pvalue: 0.0007
# done.
# --> Not Suspect ICD Code: 51636
# --> Not Suspect ICD Code: R1110
# --> Not Suspect ICD Code: 9054
# --> Not Suspect ICD Code: S32029A
# --> Not Suspect ICD Code: 71905
# --> Not Suspect ICD Code: 75563
# --> Not Suspect ICD Code: 34591
# --> Not Suspect ICD Code: 92401
# --> Not Suspect ICD Code: L709
# --> Not Suspect ICD Code: S06340A
# --> Not Suspect ICD Code: I70234
# --> Not Suspect ICD Code: F17290
# --> Not Suspect ICD Code: R142
# --> Not Suspect ICD Code: 99881
# ...
# --> Not Suspect ICD Code: 41512
# --> Not Suspect ICD Code: 2726
# --> Not Suspect ICD Code: M25519
# --> Not Suspect ICD Code: 2929
# --> Not Suspect ICD Code: E611
# --> Not Suspect ICD Code: 8738
# --> Not Suspect ICD Code: 9594
# --> Not Suspect ICD Code: Z86718
# --> Not Suspect ICD Code: V784XXA
# --> Not Suspect ICD Code: 66982
# --> Not Suspect ICD Code: 28409
# --> Not Suspect ICD Code: S2232XA
# --> Not Suspect ICD Code: 9224
# --> Not Suspect ICD Code: S72115A
# --> Not Suspect ICD Code: 4441
# --> Not Suspect ICD Code: J151
# --> Not Suspect ICD Code: 37239
# --> Not Suspect ICD Code: V5399
# --> Not Suspect ICD Code: G249
# --> Not Suspect ICD Code: 8469
# --> Not Suspect ICD Code: 2989
# --> Not Suspect ICD Code: 9916
# --> Not Suspect ICD Code: H6242
# --> Not Suspect ICD Code: 1727
# --> Not Suspect ICD Code: 30981
# --> Not Suspect ICD Code: 71230
#   chi2 test pvalue:
#     0.00084473
#   fisher test pvalue:
#     0.00263861
# start chi2 test
#   observed:
#     1.0000    2036.0000
#     4.0000    376.0000
#   expected:
#     4.2139    2032.7861
#     0.7861    379.2139
#   chi2: 11.1403
#   pvalue: 0.0008
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2036.0000
#     4.0000    376.0000
#   oddsratio: 0.0462
#   pvalue: 0.0026
# done.
# --> Not Suspect ICD Code: I4589
# --> Not Suspect ICD Code: V5867
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     80.0000    1957.0000
#     60.0000    320.0000
#   expected:
#     117.9892    1919.0108
#     22.0108    357.9892
#   chi2: 80.4225
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     80.0000    1957.0000
#     60.0000    320.0000
#   oddsratio: 0.2180
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 0661
# --> Not Suspect ICD Code: 7138
# --> Not Suspect ICD Code: V694
# --> Not Suspect ICD Code: D630
# --> Not Suspect ICD Code: A4189
# --> Not Suspect ICD Code: K5521
# --> Not Suspect ICD Code: Y92231
# --> Not Suspect ICD Code: 5569
# --> Not Suspect ICD Code: M79673
# --> Not Suspect ICD Code: E43
#   chi2 test pvalue:
#     0.00000001
#   fisher test pvalue:
#     0.00000024
# start chi2 test
#   observed:
#     24.0000    2013.0000
#     22.0000    358.0000
#   expected:
#     38.7679    1998.2321
#     7.2321    372.7679
#   chi2: 34.0475
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     24.0000    2013.0000
#     22.0000    358.0000
#   oddsratio: 0.1940
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: Y833
# --> Not Suspect ICD Code: T82838A
# --> Not Suspect ICD Code: V420
# --> Not Suspect ICD Code: 78951
#   chi2 test pvalue:
#     0.00000002
#   fisher test pvalue:
#     0.00000221
# start chi2 test
#   observed:
#     2.0000    2035.0000
#     9.0000    371.0000
#   expected:
#     9.2706    2027.7294
#     1.7294    378.2706
#   chi2: 31.5951
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2035.0000
#     9.0000    371.0000
#   oddsratio: 0.0405
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: M79652
# --> Not Suspect ICD Code: 53490
# --> Not Suspect ICD Code: 07070
# --> Not Suspect ICD Code: 2390
# --> Not Suspect ICD Code: K8071
# --> Not Suspect ICD Code: R7303
# --> Not Suspect ICD Code: 70581
# --> Not Suspect ICD Code: 43321
# --> Not Suspect ICD Code: M609
# --> Not Suspect ICD Code: 44773
# --> Not Suspect ICD Code: 65611
# --> Not Suspect ICD Code: V230
# --> Not Suspect ICD Code: 53550
#   chi2 test pvalue:
#     0.00056986
#   fisher test pvalue:
#     0.00107530
# start chi2 test
#   observed:
#     59.0000    1978.0000
#     25.0000    355.0000
#   expected:
#     70.7935    1966.2065
#     13.2065    366.7935
#   chi2: 11.8719
#   pvalue: 0.0006
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     59.0000    1978.0000
#     25.0000    355.0000
#   oddsratio: 0.4236
#   pvalue: 0.0011
# done.
# --> Not Suspect ICD Code: A6920
# --> Not Suspect ICD Code: 46619
# --> Not Suspect ICD Code: F22
# --> Not Suspect ICD Code: 99959
# --> Not Suspect ICD Code: 44321
# --> Not Suspect ICD Code: F70
# --> Not Suspect ICD Code: L989
# --> Not Suspect ICD Code: W25XXXS
# --> Not Suspect ICD Code: 7149
# --> Not Suspect ICD Code: 56489
# --> Not Suspect ICD Code: 43830
# --> Not Suspect ICD Code: G909
# --> Not Suspect ICD Code: Z8549
# --> Not Suspect ICD Code: 1539
#   chi2 test pvalue:
#     0.00409202
#   fisher test pvalue:
#     0.00693459
# start chi2 test
#   observed:
#     2.0000    2035.0000
#     4.0000    376.0000
#   expected:
#     5.0567    2031.9433
#     0.9433    379.0567
#   chi2: 8.2425
#   pvalue: 0.0041
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2035.0000
#     4.0000    376.0000
#   oddsratio: 0.0924
#   pvalue: 0.0069
# done.
# --> Not Suspect ICD Code: 78900
# --> Not Suspect ICD Code: Z96611
# --> Not Suspect ICD Code: W2212XA
# --> Not Suspect ICD Code: 1120
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000001
# start chi2 test
#   observed:
#     50.0000    1987.0000
#     35.0000    345.0000
#   expected:
#     71.6363    1965.3637
#     13.3637    366.6363
#   chi2: 41.1118
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     50.0000    1987.0000
#     35.0000    345.0000
#   oddsratio: 0.2480
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: S12500A
# --> Not Suspect ICD Code: 81305
#   chi2 test pvalue:
#     0.00128577
#   fisher test pvalue:
#     0.00386033
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   expected:
#     2.5283    2034.4717
#     0.4717    379.5283
#   chi2: 10.3628
#   pvalue: 0.0013
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     3.0000    377.0000
#   oddsratio: 0.0000
#   pvalue: 0.0039
# done.
# --> Not Suspect ICD Code: 3016
# --> Not Suspect ICD Code: 28804
# --> Not Suspect ICD Code: V4574
# --> Not Suspect ICD Code: 7566
# --> Not Suspect ICD Code: 1121
# --> Not Suspect ICD Code: 9720
# --> Not Suspect ICD Code: N210
# --> Not Suspect ICD Code: N3289
# --> Not Suspect ICD Code: L98494
# --> Not Suspect ICD Code: 3310
#   chi2 test pvalue:
#     0.00000062
#   fisher test pvalue:
#     0.00001417
# start chi2 test
#   observed:
#     7.0000    2030.0000
#     11.0000    369.0000
#   expected:
#     15.1700    2021.8300
#     2.8300    377.1700
#   chi2: 24.8513
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     7.0000    2030.0000
#     11.0000    369.0000
#   oddsratio: 0.1157
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 78059
# --> Not Suspect ICD Code: M86631
# --> Not Suspect ICD Code: F519
# --> Not Suspect ICD Code: 6239
# --> Not Suspect ICD Code: K430
# --> Not Suspect ICD Code: E83110
# --> Not Suspect ICD Code: K5650
# --> Not Suspect ICD Code: 35989
# --> Not Suspect ICD Code: 71580
# --> Not Suspect ICD Code: F17200
# --> Not Suspect ICD Code: 7847
#   chi2 test pvalue:
#     0.00000002
#   fisher test pvalue:
#     0.00000100
# start chi2 test
#   observed:
#     11.0000    2026.0000
#     15.0000    365.0000
#   expected:
#     21.9123    2015.0877
#     4.0877    375.9123
#   chi2: 31.8123
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     11.0000    2026.0000
#     15.0000    365.0000
#   oddsratio: 0.1321
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: M4855XA
# --> Not Suspect ICD Code: E271
# --> Not Suspect ICD Code: J95851
# --> Not Suspect ICD Code: 34409
# --> Not Suspect ICD Code: 28522
#   chi2 test pvalue:
#     0.00000570
#   fisher test pvalue:
#     0.00005536
# start chi2 test
#   observed:
#     9.0000    2028.0000
#     11.0000    369.0000
#   expected:
#     16.8556    2020.1444
#     3.1444    376.8556
#   chi2: 20.5871
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     9.0000    2028.0000
#     11.0000    369.0000
#   oddsratio: 0.1489
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: 5309
# --> Not Suspect ICD Code: M1389
# --> Not Suspect ICD Code: J9610
# --> Not Suspect ICD Code: V1505
# --> Not Suspect ICD Code: G40409
# --> Not Suspect ICD Code: S22059A
# --> Not Suspect ICD Code: S0990XA
# --> Not Suspect ICD Code: 72781
# --> Not Suspect ICD Code: E8809
# --> Not Suspect ICD Code: B0221
# --> Not Suspect ICD Code: 07051
# --> Not Suspect ICD Code: V4971
# --> Not Suspect ICD Code: R7881
# --> Not Suspect ICD Code: F459
# --> Not Suspect ICD Code: I82C21
# --> Not Suspect ICD Code: 51189
# --> Not Suspect ICD Code: 1919
# --> Not Suspect ICD Code: Q984
# --> Not Suspect ICD Code: M4856XD
# --> Not Suspect ICD Code: 75617
# --> Not Suspect ICD Code: 37924
# --> Not Suspect ICD Code: T8641
# --> Not Suspect ICD Code: 78321
# --> Not Suspect ICD Code: 25093
# --> Not Suspect ICD Code: 30250
# --> Not Suspect ICD Code: 9062
# --> Not Suspect ICD Code: 36614
# --> Not Suspect ICD Code: R202
# --> Not Suspect ICD Code: E0590
# --> Not Suspect ICD Code: B441
# --> Not Suspect ICD Code: 40591
# --> Not Suspect ICD Code: 68101
# --> Not Suspect ICD Code: M10072
# --> Not Suspect ICD Code: 2409
# --> Not Suspect ICD Code: G90522
# --> Not Suspect ICD Code: R41840
# --> Not Suspect ICD Code: 8831
# --> Not Suspect ICD Code: 78442
# --> Not Suspect ICD Code: V558
# --> Not Suspect ICD Code: I898
# --> Not Suspect ICD Code: 37732
# --> Not Suspect ICD Code: 7014
# --> Not Suspect ICD Code: E9305
# --> Not Suspect ICD Code: M86171
# --> Not Suspect ICD Code: 07799
# --> Not Suspect ICD Code: Z720
# --> Not Suspect ICD Code: 3014
# --> Not Suspect ICD Code: C50912
# --> Not Suspect ICD Code: L0231
# --> Not Suspect ICD Code: 5582
# --> Not Suspect ICD Code: 30523
# --> Not Suspect ICD Code: 58389
# --> Not Suspect ICD Code: 75612
# --> Not Suspect ICD Code: Z6826
# --> Not Suspect ICD Code: 63491
# --> Not Suspect ICD Code: M7918
# --> Not Suspect ICD Code: R6881
# --> Not Suspect ICD Code: V8537
# --> Not Suspect ICD Code: E099
# --> Not Suspect ICD Code: E8794
# --> Not Suspect ICD Code: 67524
# --> Not Suspect ICD Code: 9534
# --> Not Suspect ICD Code: D7589
# --> Not Suspect ICD Code: 6823
# --> Not Suspect ICD Code: G43009
# --> Not Suspect ICD Code: 6258
# --> Not Suspect ICD Code: 5778
# --> Not Suspect ICD Code: 27730
# --> Not Suspect ICD Code: N189
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000007
# start chi2 test
#   observed:
#     39.0000    1998.0000
#     29.0000    351.0000
#   expected:
#     57.3091    1979.6909
#     10.6909    369.3091
#   chi2: 36.2197
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     39.0000    1998.0000
#     29.0000    351.0000
#   oddsratio: 0.2363
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 4541
# --> Not Suspect ICD Code: R402252
# --> Not Suspect ICD Code: 78829
# --> Not Suspect ICD Code: M19071
# --> Not Suspect ICD Code: Z6835
# --> Not Suspect ICD Code: 72705
# --> Not Suspect ICD Code: 71105
# --> Not Suspect ICD Code: M4628
# --> Not Suspect ICD Code: K056
# --> Not Suspect ICD Code: Z431
# --> Not Suspect ICD Code: N453
# --> Not Suspect ICD Code: N529
# --> Not Suspect ICD Code: 463
# --> Not Suspect ICD Code: S52592A
# --> Not Suspect ICD Code: I82431
#   chi2 test pvalue:
#     0.00007913
#   fisher test pvalue:
#     0.00060288
# start chi2 test
#   observed:
#     0.0000    2037.0000
#     4.0000    376.0000
#   expected:
#     3.3711    2033.6289
#     0.6289    379.3711
#   chi2: 15.5791
#   pvalue: 0.0001
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     0.0000    2037.0000
#     4.0000    376.0000
#   oddsratio: 0.0000
#   pvalue: 0.0006
# done.
# --> Not Suspect ICD Code: F312
# --> Not Suspect ICD Code: H5462
# --> Not Suspect ICD Code: I82721
# --> Not Suspect ICD Code: V1369
# --> Not Suspect ICD Code: J9612
# --> Not Suspect ICD Code: 1737
# --> Not Suspect ICD Code: K122
# --> Not Suspect ICD Code: 2863
# --> Not Suspect ICD Code: F11988
# --> Not Suspect ICD Code: 53291
# --> Not Suspect ICD Code: 5724
# --> Not Suspect ICD Code: 6272
# --> Not Suspect ICD Code: 3543
# --> Not Suspect ICD Code: O99324
# --> Not Suspect ICD Code: C784
# --> Not Suspect ICD Code: Z902
# --> Not Suspect ICD Code: 4719
# --> Not Suspect ICD Code: K56699
# --> Not Suspect ICD Code: G8220
# --> Not Suspect ICD Code: 6850
# --> Not Suspect ICD Code: 19889
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000030
# start chi2 test
#   observed:
#     3.0000    2034.0000
#     11.0000    369.0000
#   expected:
#     11.7989    2025.2011
#     2.2011    377.7989
#   chi2: 37.3437
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2034.0000
#     11.0000    369.0000
#   oddsratio: 0.0495
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: Z86006
# --> Not Suspect ICD Code: O99712
# --> Not Suspect ICD Code: 3510
# --> Not Suspect ICD Code: T420X6A
# --> Not Suspect ICD Code: 1748
# --> Not Suspect ICD Code: V1509
# --> Not Suspect ICD Code: 66942
# --> Not Suspect ICD Code: 340
# --> Not Suspect ICD Code: T8029XA
# --> Not Suspect ICD Code: Y849
# --> Not Suspect ICD Code: I83018
# --> Not Suspect ICD Code: T8189XA
# --> Not Suspect ICD Code: 0038
# --> Not Suspect ICD Code: F502
# --> Not Suspect ICD Code: E538
# --> Not Suspect ICD Code: M4855XD
# --> Not Suspect ICD Code: S2231XD
# --> Not Suspect ICD Code: E041
# --> Not Suspect ICD Code: 27949
# --> Not Suspect ICD Code: N762
# --> Not Suspect ICD Code: 2768
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     152.0000    1885.0000
#     76.0000    304.0000
#   expected:
#     192.1539    1844.8461
#     35.8461    344.1539
#   chi2: 57.4707
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     152.0000    1885.0000
#     76.0000    304.0000
#   oddsratio: 0.3225
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: O99284
# --> Not Suspect ICD Code: S50311A
# --> Not Suspect ICD Code: 5959
# --> Not Suspect ICD Code: O4292
# --> Not Suspect ICD Code: Z79891
# --> Not Suspect ICD Code: 9984
# --> Not Suspect ICD Code: V1091
# --> Not Suspect ICD Code: 5283
# --> Not Suspect ICD Code: K50012
# --> Not Suspect ICD Code: 2888
# --> Not Suspect ICD Code: 81351
# --> Not Suspect ICD Code: O9089
# --> Not Suspect ICD Code: 75839
# --> Not Suspect ICD Code: 99832
# --> Not Suspect ICD Code: R209
# --> Not Suspect ICD Code: V8533
# --> Not Suspect ICD Code: 1404
# --> Not Suspect ICD Code: S60212A
# --> Not Suspect ICD Code: 4419
# --> Not Suspect ICD Code: B369
# --> Not Suspect ICD Code: 2822
# --> Not Suspect ICD Code: F5001
# --> Not Suspect ICD Code: K1120
# --> Not Suspect ICD Code: D67
# --> Not Suspect ICD Code: 4559
# --> Not Suspect ICD Code: R760
# --> Not Suspect ICD Code: 59969
# --> Not Suspect ICD Code: I82622
# --> Not Suspect ICD Code: 07811
# --> Not Suspect ICD Code: V149
# --> Not Suspect ICD Code: 65411
# --> Not Suspect ICD Code: 4470
# --> Not Suspect ICD Code: 7213
# --> Not Suspect ICD Code: Z4502
# --> Not Suspect ICD Code: 65171
# --> Not Suspect ICD Code: 65581
# --> Not Suspect ICD Code: M86662
# --> Not Suspect ICD Code: 78863
# --> Not Suspect ICD Code: G510
# --> Not Suspect ICD Code: G4440
# --> Not Suspect ICD Code: G894
# --> Not Suspect ICD Code: I9742
# --> Not Suspect ICD Code: K5902
# --> Not Suspect ICD Code: 04186
# --> Not Suspect ICD Code: V449
# --> Not Suspect ICD Code: M25432
# --> Not Suspect ICD Code: 677
# --> Not Suspect ICD Code: R4182
# --> Not Suspect ICD Code: T461X1A
# --> Not Suspect ICD Code: W109XXA
# --> Not Suspect ICD Code: 5990
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     208.0000    1829.0000
#     144.0000    236.0000
#   expected:
#     296.6587    1740.3413
#     55.3413    324.6587
#   chi2: 195.0395
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     208.0000    1829.0000
#     144.0000    236.0000
#   oddsratio: 0.1864
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: I77810
# --> Not Suspect ICD Code: 53111
# --> Not Suspect ICD Code: R0603
# --> Not Suspect ICD Code: N83201
# --> Not Suspect ICD Code: N183
# --> Not Suspect ICD Code: K588
# --> Not Suspect ICD Code: D563
# --> Not Suspect ICD Code: C773
# --> Not Suspect ICD Code: N4822
# --> Not Suspect ICD Code: C44329
# --> Not Suspect ICD Code: 71236
# --> Not Suspect ICD Code: 7078
#   chi2 test pvalue:
#     0.00003773
#   fisher test pvalue:
#     0.00020008
# start chi2 test
#   observed:
#     9.0000    2028.0000
#     10.0000    370.0000
#   expected:
#     16.0128    2020.9872
#     2.9872    377.0128
#   chi2: 16.9821
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     9.0000    2028.0000
#     10.0000    370.0000
#   oddsratio: 0.1642
#   pvalue: 0.0002
# done.
# --> Not Suspect ICD Code: I671
# --> Not Suspect ICD Code: N138
# --> Not Suspect ICD Code: 20512
# --> Not Suspect ICD Code: S23162A
# --> Not Suspect ICD Code: 5829
# --> Not Suspect ICD Code: 7936
# --> Not Suspect ICD Code: 3379

# %% [markdown]
# # df_ibd and df_no_ibd

# %%
suspect_icd_codes = ['2724', '27651', '2859', '30000', '311', '4019', '53081', '5849', 'V1582']

for suspect_icd_code in suspect_icd_codes:
    pvalue1 = construct_chi2_test(df_ibd, df_no_ibd, suspect_icd_code, silent=True)
    pvalue2 = construct_fisher_test(df_ibd, df_no_ibd, suspect_icd_code, silent=True)

    if pvalue1 <= 0.005 or pvalue2 <= 0.05:
        print('--> Suspect ICD Code: {}'.format(suspect_icd_code))
        print('  chi2 test pvalue:\n    {:.8f}'.format(pvalue1))
        print('  fisher test pvalue:\n    {:.8f}'.format(pvalue2))
        
        pvalue1 = construct_chi2_test(df_ibd, df_no_ibd, suspect_icd_code, silent=False)
        pvalue2 = construct_fisher_test(df_ibd, df_no_ibd, suspect_icd_code, silent=False)

    
    # break
# Out:
# --> Suspect ICD Code: 2724
#   chi2 test pvalue:
#     0.02564857
#   fisher test pvalue:
#     0.02512313
# start chi2 test
#   observed:
#     491.0000    1926.0000
#     33448.0000    147179.0000
#   expected:
#     448.1467    1968.8533
#     33490.8533    147136.1467
#   chi2: 4.9796
#   pvalue: 0.0256
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     491.0000    1926.0000
#     33448.0000    147179.0000
#   oddsratio: 1.1218
#   pvalue: 0.0251
# done.
# --> Suspect ICD Code: 27651
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     409.0000    2008.0000
#     8355.0000    172272.0000
#   expected:
#     115.7240    2301.2760
#     8648.2760    171978.7240
#   chi2: 788.3664
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     409.0000    2008.0000
#     8355.0000    172272.0000
#   oddsratio: 4.1998
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 2859
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     523.0000    1894.0000
#     16592.0000    164035.0000
#   expected:
#     225.9946    2191.0054
#     16889.0054    163737.9946
#   chi2: 434.8838
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     523.0000    1894.0000
#     16592.0000    164035.0000
#   oddsratio: 2.7300
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 30000
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     439.0000    1978.0000
#     13705.0000    166922.0000
#   expected:
#     186.7641    2230.2359
#     13957.2359    166669.7641
#   chi2: 372.6452
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     439.0000    1978.0000
#     13705.0000    166922.0000
#   oddsratio: 2.7032
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 311
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     502.0000    1915.0000
#     19216.0000    161411.0000
#   expected:
#     260.3658    2156.6342
#     19457.6342    161169.3658
#   chi2: 253.6334
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     502.0000    1915.0000
#     19216.0000    161411.0000
#   oddsratio: 2.2019
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 4019
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     810.0000    1607.0000
#     49741.0000    130886.0000
#   expected:
#     667.4994    1749.5006
#     49883.5006    130743.4994
#   chi2: 42.2926
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     810.0000    1607.0000
#     49741.0000    130886.0000
#   oddsratio: 1.3263
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 53081
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     678.0000    1739.0000
#     23955.0000    156672.0000
#   expected:
#     325.2658    2091.7342
#     24307.7342    156319.2658
#   chi2: 446.6501
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     678.0000    1739.0000
#     23955.0000    156672.0000
#   oddsratio: 2.5499
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: 5849
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     448.0000    1969.0000
#     17295.0000    163332.0000
#   expected:
#     234.2870    2182.7130
#     17508.7130    163118.2870
#   chi2: 217.7369
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     448.0000    1969.0000
#     17295.0000    163332.0000
#   oddsratio: 2.1487
#   pvalue: 0.0000
# done.
# --> Suspect ICD Code: V1582
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     503.0000    1914.0000
#     17849.0000    162778.0000
#   expected:
#     242.3285    2174.6715
#     18109.6715    162517.3285
#   chi2: 314.6086
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     503.0000    1914.0000
#     17849.0000    162778.0000
#   oddsratio: 2.3967
#   pvalue: 0.0000
# done.

# %%
not_suspect_icd_code = list(
        set(df_no_ibd['icd_code'].unique().tolist()) | \
            set(df_ibd['icd_code'].unique().tolist()) - \
                set(suspect_icd_codes)
    )[:]

for not_suspect_icd_code in not_suspect_icd_code:
    print('--> Not Suspect ICD Code: {}'.format(not_suspect_icd_code))
    pvalue1 = construct_chi2_test(df_ibd, df_no_ibd, not_suspect_icd_code, silent=True)
    pvalue2 = construct_fisher_test(df_ibd, df_no_ibd, not_suspect_icd_code, silent=True)
    
    if pvalue1 <= 0.01 or pvalue2 <= 0.01:
        print('  chi2 test pvalue:\n    {:.8f}'.format(pvalue1))
        print('  fisher test pvalue:\n    {:.8f}'.format(pvalue2))
        
        pvalue1 = construct_chi2_test(df_ibd, df_no_ibd, not_suspect_icd_code, silent=False)
        pvalue2 = construct_fisher_test(df_ibd, df_no_ibd, not_suspect_icd_code, silent=False)
    
    # break
# Out:
# --> Not Suspect ICD Code: I6622
# --> Not Suspect ICD Code: S68623S
# --> Not Suspect ICD Code: 24290
# --> Not Suspect ICD Code: 43301
# --> Not Suspect ICD Code: M62838
# --> Not Suspect ICD Code: Q661
# --> Not Suspect ICD Code: 42789
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     205.0000    2212.0000
#     7404.0000    173223.0000
#   expected:
#     100.4729    2316.5271
#     7508.5271    173118.4729
#   chi2: 113.8824
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     205.0000    2212.0000
#     7404.0000    173223.0000
#   oddsratio: 2.1682
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: T82128A
# --> Not Suspect ICD Code: V189XXA
# --> Not Suspect ICD Code: 36922
# --> Not Suspect ICD Code: 24900
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     25.0000    2392.0000
#     422.0000    180205.0000
#   expected:
#     5.9024    2411.0976
#     441.0976    180185.9024
#   chi2: 59.5278
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     25.0000    2392.0000
#     422.0000    180205.0000
#   oddsratio: 4.4631
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: R198
# --> Not Suspect ICD Code: I97121
# --> Not Suspect ICD Code: 82539
# --> Not Suspect ICD Code: T8502XS
# --> Not Suspect ICD Code: 5375
# --> Not Suspect ICD Code: G59
# --> Not Suspect ICD Code: K111
# --> Not Suspect ICD Code: K740
# --> Not Suspect ICD Code: 48240
# --> Not Suspect ICD Code: K614
#   chi2 test pvalue:
#     0.00322945
#   fisher test pvalue:
#     0.01632711
# start chi2 test
#   observed:
#     2.0000    2415.0000
#     13.0000    180614.0000
#   expected:
#     0.1981    2416.8019
#     14.8019    180612.1981
#   chi2: 8.6731
#   pvalue: 0.0032
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2415.0000
#     13.0000    180614.0000
#   oddsratio: 11.5059
#   pvalue: 0.0163
# done.
# --> Not Suspect ICD Code: I69854
# --> Not Suspect ICD Code: 80136
# --> Not Suspect ICD Code: 37946
# --> Not Suspect ICD Code: M11861
# --> Not Suspect ICD Code: R4181
# --> Not Suspect ICD Code: Y9229
# --> Not Suspect ICD Code: 28952
# --> Not Suspect ICD Code: V812
# --> Not Suspect ICD Code: S12401A
# --> Not Suspect ICD Code: M10061
# --> Not Suspect ICD Code: 74789
# --> Not Suspect ICD Code: 2669
# --> Not Suspect ICD Code: E9063
# --> Not Suspect ICD Code: S2241XA
# --> Not Suspect ICD Code: 57149
# --> Not Suspect ICD Code: E164
# --> Not Suspect ICD Code: R29818
# --> Not Suspect ICD Code: R2241
# --> Not Suspect ICD Code: S5782XA
# --> Not Suspect ICD Code: M07649
#   chi2 test pvalue:
#     0.00334941
#   fisher test pvalue:
#     0.02623466
# start chi2 test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   expected:
#     0.0264    2416.9736
#     1.9736    180625.0264
#   chi2: 8.6066
#   pvalue: 0.0033
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   oddsratio: 74.7624
#   pvalue: 0.0262
# done.
# --> Not Suspect ICD Code: S82302E
# --> Not Suspect ICD Code: O99834
# --> Not Suspect ICD Code: S63095A
# --> Not Suspect ICD Code: J111
# --> Not Suspect ICD Code: M21072
# --> Not Suspect ICD Code: 1451
# --> Not Suspect ICD Code: M00062
# --> Not Suspect ICD Code: I70702
# --> Not Suspect ICD Code: I97631
# --> Not Suspect ICD Code: J940
# --> Not Suspect ICD Code: F15188
# --> Not Suspect ICD Code: Z9225
# --> Not Suspect ICD Code: S37061A
# --> Not Suspect ICD Code: T3390XA
# --> Not Suspect ICD Code: Z3491
# --> Not Suspect ICD Code: 86221
# --> Not Suspect ICD Code: M4634
# --> Not Suspect ICD Code: H53469
# --> Not Suspect ICD Code: 6944
# --> Not Suspect ICD Code: M87271
# --> Not Suspect ICD Code: M7052
# --> Not Suspect ICD Code: E9224
# --> Not Suspect ICD Code: 28984
#   chi2 test pvalue:
#     0.00368387
#   fisher test pvalue:
#     0.00665434
# start chi2 test
#   observed:
#     8.0000    2409.0000
#     199.0000    180428.0000
#   expected:
#     2.7333    2414.2667
#     204.2667    180422.7333
#   chi2: 8.4334
#   pvalue: 0.0037
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     8.0000    2409.0000
#     199.0000    180428.0000
#   oddsratio: 3.0110
#   pvalue: 0.0067
# done.
# --> Not Suspect ICD Code: 85241
# --> Not Suspect ICD Code: 78003
# --> Not Suspect ICD Code: 71782
# --> Not Suspect ICD Code: S93422A
# --> Not Suspect ICD Code: S22038A
# --> Not Suspect ICD Code: 1734
# --> Not Suspect ICD Code: L560
# --> Not Suspect ICD Code: Q670
# --> Not Suspect ICD Code: S14114A
# --> Not Suspect ICD Code: C8444
# --> Not Suspect ICD Code: 29020
# --> Not Suspect ICD Code: 4281
# --> Not Suspect ICD Code: S8781XA
# --> Not Suspect ICD Code: H4720
# --> Not Suspect ICD Code: S89202A
# --> Not Suspect ICD Code: I612
# --> Not Suspect ICD Code: L97502
# --> Not Suspect ICD Code: Q51818
# --> Not Suspect ICD Code: C50011
# --> Not Suspect ICD Code: J95830
# --> Not Suspect ICD Code: S36222A
# --> Not Suspect ICD Code: D494
# --> Not Suspect ICD Code: R936
# --> Not Suspect ICD Code: 4532
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00001004
# start chi2 test
#   observed:
#     10.0000    2407.0000
#     120.0000    180507.0000
#   expected:
#     1.7166    2415.2834
#     128.2834    180498.7166
#   chi2: 35.7897
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2407.0000
#     120.0000    180507.0000
#   oddsratio: 6.2494
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 4552
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     25.0000    2392.0000
#     435.0000    180192.0000
#   expected:
#     6.0741    2410.9259
#     453.9259    180173.0741
#   chi2: 56.7866
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     25.0000    2392.0000
#     435.0000    180192.0000
#   oddsratio: 4.3294
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 7038
# --> Not Suspect ICD Code: D702
# --> Not Suspect ICD Code: 53211
# --> Not Suspect ICD Code: 17381
# --> Not Suspect ICD Code: E870
#   chi2 test pvalue:
#     0.00527087
#   fisher test pvalue:
#     0.00279917
# start chi2 test
#   observed:
#     22.0000    2395.0000
#     2996.0000    177631.0000
#   expected:
#     39.8511    2377.1489
#     2978.1489    177648.8511
#   chi2: 7.7841
#   pvalue: 0.0053
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     22.0000    2395.0000
#     2996.0000    177631.0000
#   oddsratio: 0.5446
#   pvalue: 0.0028
# done.
# --> Not Suspect ICD Code: 6244
# --> Not Suspect ICD Code: M24222
# --> Not Suspect ICD Code: T43015S
# --> Not Suspect ICD Code: T731XXA
# --> Not Suspect ICD Code: S73192A
# --> Not Suspect ICD Code: 20160
# --> Not Suspect ICD Code: T791XXA
# --> Not Suspect ICD Code: 67121
# --> Not Suspect ICD Code: E0843
# --> Not Suspect ICD Code: 3361
# --> Not Suspect ICD Code: Y92838
# --> Not Suspect ICD Code: E113499
# --> Not Suspect ICD Code: 51281
# --> Not Suspect ICD Code: S0086XA
# --> Not Suspect ICD Code: S91135A
# --> Not Suspect ICD Code: Q71892
# --> Not Suspect ICD Code: H6121
# --> Not Suspect ICD Code: Z716
# --> Not Suspect ICD Code: G500
# --> Not Suspect ICD Code: 7503
# --> Not Suspect ICD Code: 65131
# --> Not Suspect ICD Code: S22079D
# --> Not Suspect ICD Code: 8602
# --> Not Suspect ICD Code: M60000
# --> Not Suspect ICD Code: Z22330
# --> Not Suspect ICD Code: Y92328
# --> Not Suspect ICD Code: 8860
# --> Not Suspect ICD Code: S99921S
# --> Not Suspect ICD Code: T3995XA
# --> Not Suspect ICD Code: 20951
# --> Not Suspect ICD Code: K0253
# --> Not Suspect ICD Code: S86011A
# --> Not Suspect ICD Code: S24102D
# --> Not Suspect ICD Code: V5427
#   chi2 test pvalue:
#     0.00000315
#   fisher test pvalue:
#     0.00350221
# start chi2 test
#   observed:
#     2.0000    2415.0000
#     5.0000    180622.0000
#   expected:
#     0.0924    2416.9076
#     6.9076    180620.0924
#   chi2: 21.7225
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2415.0000
#     5.0000    180622.0000
#   oddsratio: 29.9167
#   pvalue: 0.0035
# done.
# --> Not Suspect ICD Code: I659
# --> Not Suspect ICD Code: T83021A
# --> Not Suspect ICD Code: W108XXA
# --> Not Suspect ICD Code: S60562A
# --> Not Suspect ICD Code: Z6832
# --> Not Suspect ICD Code: R2232
# --> Not Suspect ICD Code: A078
# --> Not Suspect ICD Code: 8364
# --> Not Suspect ICD Code: 3882
# --> Not Suspect ICD Code: 7352
# --> Not Suspect ICD Code: O9872
# --> Not Suspect ICD Code: 81510
# --> Not Suspect ICD Code: V4962
# --> Not Suspect ICD Code: A227
# --> Not Suspect ICD Code: F600
# --> Not Suspect ICD Code: 92820
# --> Not Suspect ICD Code: 29189
# --> Not Suspect ICD Code: S12110S
# --> Not Suspect ICD Code: S62620B
# --> Not Suspect ICD Code: 9562
# --> Not Suspect ICD Code: M79A3
# --> Not Suspect ICD Code: S32139A
# --> Not Suspect ICD Code: R230
# --> Not Suspect ICD Code: C44221
# --> Not Suspect ICD Code: M619
# --> Not Suspect ICD Code: 3668
# --> Not Suspect ICD Code: T8119XA
# --> Not Suspect ICD Code: M910
# --> Not Suspect ICD Code: K439
# --> Not Suspect ICD Code: M1A9XX0
# --> Not Suspect ICD Code: Z5339
# --> Not Suspect ICD Code: O9A32
# --> Not Suspect ICD Code: 08249
# --> Not Suspect ICD Code: 2374
# --> Not Suspect ICD Code: 66602
# --> Not Suspect ICD Code: H00019
# --> Not Suspect ICD Code: M6250
# --> Not Suspect ICD Code: M4134
# --> Not Suspect ICD Code: 29212
# --> Not Suspect ICD Code: D7289
# --> Not Suspect ICD Code: J339
# --> Not Suspect ICD Code: I82C29
# --> Not Suspect ICD Code: H2510
# --> Not Suspect ICD Code: 65913
# --> Not Suspect ICD Code: S14112A
# --> Not Suspect ICD Code: H68003
# --> Not Suspect ICD Code: 1125
#   chi2 test pvalue:
#     0.00000294
#   fisher test pvalue:
#     0.00015206
# start chi2 test
#   observed:
#     10.0000    2407.0000
#     169.0000    180458.0000
#   expected:
#     2.3636    2414.6364
#     176.6364    180450.3636
#   chi2: 21.8566
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2407.0000
#     169.0000    180458.0000
#   oddsratio: 4.4362
#   pvalue: 0.0002
# done.
# --> Not Suspect ICD Code: O9973
# --> Not Suspect ICD Code: M5387
# --> Not Suspect ICD Code: V2512
# --> Not Suspect ICD Code: Y92210
# --> Not Suspect ICD Code: M11279
#   chi2 test pvalue:
#     0.00334941
#   fisher test pvalue:
#     0.02623466
# start chi2 test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   expected:
#     0.0264    2416.9736
#     1.9736    180625.0264
#   chi2: 8.6066
#   pvalue: 0.0033
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   oddsratio: 74.7624
#   pvalue: 0.0262
# done.
# --> Not Suspect ICD Code: 28730
# --> Not Suspect ICD Code: V6103
# --> Not Suspect ICD Code: 42491
# --> Not Suspect ICD Code: S24103D
# --> Not Suspect ICD Code: J852
# --> Not Suspect ICD Code: O30133
# --> Not Suspect ICD Code: C49A9
# --> Not Suspect ICD Code: D1339
# --> Not Suspect ICD Code: L98411
# --> Not Suspect ICD Code: 4881
# --> Not Suspect ICD Code: E9190
# --> Not Suspect ICD Code: 36040
# --> Not Suspect ICD Code: T85818A
# --> Not Suspect ICD Code: S61251D
# --> Not Suspect ICD Code: A401
# --> Not Suspect ICD Code: 4270
# --> Not Suspect ICD Code: S06350A
# --> Not Suspect ICD Code: S00432A
# --> Not Suspect ICD Code: S90521A
# --> Not Suspect ICD Code: 37991
# --> Not Suspect ICD Code: M5091
# --> Not Suspect ICD Code: I69192
# --> Not Suspect ICD Code: 82030
# --> Not Suspect ICD Code: T194XXA
# --> Not Suspect ICD Code: M86611
# --> Not Suspect ICD Code: H43393
# --> Not Suspect ICD Code: S42125A
# --> Not Suspect ICD Code: 30423
# --> Not Suspect ICD Code: 42822
# --> Not Suspect ICD Code: M2350
# --> Not Suspect ICD Code: I87009
# --> Not Suspect ICD Code: 3968
# --> Not Suspect ICD Code: 72706
# --> Not Suspect ICD Code: 29664
# --> Not Suspect ICD Code: 63390
# --> Not Suspect ICD Code: Q282
# --> Not Suspect ICD Code: 30722
# --> Not Suspect ICD Code: A599
# --> Not Suspect ICD Code: H2630
# --> Not Suspect ICD Code: T8332XA
# --> Not Suspect ICD Code: M00821
# --> Not Suspect ICD Code: S92325A
# --> Not Suspect ICD Code: C130
# --> Not Suspect ICD Code: I25790
# --> Not Suspect ICD Code: S61315A
# --> Not Suspect ICD Code: M898X8
# --> Not Suspect ICD Code: M25531
# --> Not Suspect ICD Code: H5359
# --> Not Suspect ICD Code: F323
# --> Not Suspect ICD Code: S5782XS
# --> Not Suspect ICD Code: E7521
# --> Not Suspect ICD Code: S065X0D
# --> Not Suspect ICD Code: N055
# --> Not Suspect ICD Code: 36910
# --> Not Suspect ICD Code: 2728
# --> Not Suspect ICD Code: E9530
# --> Not Suspect ICD Code: V623
# --> Not Suspect ICD Code: S92212A
# --> Not Suspect ICD Code: M25675
# --> Not Suspect ICD Code: C8410
# --> Not Suspect ICD Code: S0265XK
# --> Not Suspect ICD Code: M07671
# --> Not Suspect ICD Code: Z3A32
# --> Not Suspect ICD Code: T528X4A
# --> Not Suspect ICD Code: 80146
# --> Not Suspect ICD Code: Z332
# --> Not Suspect ICD Code: B941
# --> Not Suspect ICD Code: 74742
# --> Not Suspect ICD Code: 86349
# --> Not Suspect ICD Code: 01505
# --> Not Suspect ICD Code: M25451
# --> Not Suspect ICD Code: 3371
# --> Not Suspect ICD Code: S42342K
# --> Not Suspect ICD Code: D2121
# --> Not Suspect ICD Code: S82092K
# --> Not Suspect ICD Code: K257
# --> Not Suspect ICD Code: T511X2A
# --> Not Suspect ICD Code: S82262B
# --> Not Suspect ICD Code: J0430
# --> Not Suspect ICD Code: A771
# --> Not Suspect ICD Code: M62512
# --> Not Suspect ICD Code: 80220
# --> Not Suspect ICD Code: S27301A
# --> Not Suspect ICD Code: 75672
# --> Not Suspect ICD Code: G218
# --> Not Suspect ICD Code: 5952
#   chi2 test pvalue:
#     0.00376539
#   fisher test pvalue:
#     0.01279146
# start chi2 test
#   observed:
#     3.0000    2414.0000
#     34.0000    180593.0000
#   expected:
#     0.4886    2416.5114
#     36.5114    180590.4886
#   chi2: 8.3936
#   pvalue: 0.0038
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2414.0000
#     34.0000    180593.0000
#   oddsratio: 6.6009
#   pvalue: 0.0128
# done.
# --> Not Suspect ICD Code: I69922
# --> Not Suspect ICD Code: S6412XA
# --> Not Suspect ICD Code: D72821
# --> Not Suspect ICD Code: 9500
# --> Not Suspect ICD Code: M3481
# --> Not Suspect ICD Code: 7222
#   chi2 test pvalue:
#     0.00000013
#   fisher test pvalue:
#     0.00005614
# start chi2 test
#   observed:
#     9.0000    2408.0000
#     119.0000    180508.0000
#   expected:
#     1.6902    2415.3098
#     126.3098    180500.6902
#   chi2: 27.8239
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     9.0000    2408.0000
#     119.0000    180508.0000
#   oddsratio: 5.6694
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: L89300
# --> Not Suspect ICD Code: 27904
# --> Not Suspect ICD Code: S52131B
# --> Not Suspect ICD Code: T392X5A
# --> Not Suspect ICD Code: H9121
# --> Not Suspect ICD Code: 37852
# --> Not Suspect ICD Code: Z207
# --> Not Suspect ICD Code: 2639
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     152.0000    2265.0000
#     2464.0000    178163.0000
#   expected:
#     34.5429    2382.4571
#     2581.4571    178045.5429
#   chi2: 407.1164
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     152.0000    2265.0000
#     2464.0000    178163.0000
#   oddsratio: 4.8524
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: G254
# --> Not Suspect ICD Code: E756
# --> Not Suspect ICD Code: X500XXD
# --> Not Suspect ICD Code: S62393A
# --> Not Suspect ICD Code: 9711
# --> Not Suspect ICD Code: 60490
# --> Not Suspect ICD Code: C44321
# --> Not Suspect ICD Code: G839
# --> Not Suspect ICD Code: Q248
# --> Not Suspect ICD Code: T4276XA
# --> Not Suspect ICD Code: C9200
# --> Not Suspect ICD Code: M4814
# --> Not Suspect ICD Code: 0413
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     51.0000    2366.0000
#     1441.0000    179186.0000
#   expected:
#     19.7011    2397.2989
#     1472.2989    179154.7011
#   chi2: 49.1936
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     51.0000    2366.0000
#     1441.0000    179186.0000
#   oddsratio: 2.6804
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 5982
# --> Not Suspect ICD Code: Z08
# --> Not Suspect ICD Code: S0240CD
# --> Not Suspect ICD Code: 86600
# --> Not Suspect ICD Code: H93A2
# --> Not Suspect ICD Code: H541131
# --> Not Suspect ICD Code: 4378
# --> Not Suspect ICD Code: E9179
# --> Not Suspect ICD Code: M21619
# --> Not Suspect ICD Code: S91125A
# --> Not Suspect ICD Code: R5382
# --> Not Suspect ICD Code: 53909
# --> Not Suspect ICD Code: I952
# --> Not Suspect ICD Code: 30928
#   chi2 test pvalue:
#     0.00000172
#   fisher test pvalue:
#     0.00008535
# start chi2 test
#   observed:
#     12.0000    2405.0000
#     224.0000    180403.0000
#   expected:
#     3.1163    2413.8837
#     232.8837    180394.1163
#   chi2: 22.8863
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     12.0000    2405.0000
#     224.0000    180403.0000
#   oddsratio: 4.0185
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: R339
# --> Not Suspect ICD Code: O2693
# --> Not Suspect ICD Code: 7366
# --> Not Suspect ICD Code: Z9350
# --> Not Suspect ICD Code: T443X2A
# --> Not Suspect ICD Code: S61245A
# --> Not Suspect ICD Code: D470
# --> Not Suspect ICD Code: T400X6A
#   chi2 test pvalue:
#     0.00334941
#   fisher test pvalue:
#     0.02623466
# start chi2 test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   expected:
#     0.0264    2416.9736
#     1.9736    180625.0264
#   chi2: 8.6066
#   pvalue: 0.0033
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   oddsratio: 74.7624
#   pvalue: 0.0262
# done.
# --> Not Suspect ICD Code: E9353
# --> Not Suspect ICD Code: 42291
# --> Not Suspect ICD Code: L02612
# --> Not Suspect ICD Code: M71151
# --> Not Suspect ICD Code: M10041
# --> Not Suspect ICD Code: E9385
# --> Not Suspect ICD Code: D609
# --> Not Suspect ICD Code: E8781
# --> Not Suspect ICD Code: M80051D
# --> Not Suspect ICD Code: 1571
# --> Not Suspect ICD Code: M7061
# --> Not Suspect ICD Code: M25642
# --> Not Suspect ICD Code: S7290XD
# --> Not Suspect ICD Code: I6529
# --> Not Suspect ICD Code: K823
# --> Not Suspect ICD Code: 78763
# --> Not Suspect ICD Code: S7011XA
# --> Not Suspect ICD Code: G7102
# --> Not Suspect ICD Code: Z9181
# --> Not Suspect ICD Code: 6398
# --> Not Suspect ICD Code: R785
# --> Not Suspect ICD Code: Z6836
# --> Not Suspect ICD Code: J9312
# --> Not Suspect ICD Code: O658
# --> Not Suspect ICD Code: 8961
# --> Not Suspect ICD Code: T69022A
# --> Not Suspect ICD Code: S56421A
# --> Not Suspect ICD Code: V151
# --> Not Suspect ICD Code: 59011
# --> Not Suspect ICD Code: G5682
# --> Not Suspect ICD Code: V532
# --> Not Suspect ICD Code: Z952
# --> Not Suspect ICD Code: 37999
# --> Not Suspect ICD Code: S01111A
# --> Not Suspect ICD Code: R9349
# --> Not Suspect ICD Code: S40011A
# --> Not Suspect ICD Code: T8612
# --> Not Suspect ICD Code: 8500
# --> Not Suspect ICD Code: 38812
# --> Not Suspect ICD Code: 87323
# --> Not Suspect ICD Code: 53783
# --> Not Suspect ICD Code: B829
# --> Not Suspect ICD Code: 36645
# --> Not Suspect ICD Code: 37001
# --> Not Suspect ICD Code: R1902
# --> Not Suspect ICD Code: 9009
# --> Not Suspect ICD Code: S02402B
# --> Not Suspect ICD Code: V5871
# --> Not Suspect ICD Code: C8441
# --> Not Suspect ICD Code: 3868
# --> Not Suspect ICD Code: 66031
# --> Not Suspect ICD Code: Y92320
# --> Not Suspect ICD Code: O458X2
# --> Not Suspect ICD Code: M87821
# --> Not Suspect ICD Code: 4588
#   chi2 test pvalue:
#     0.00000001
#   fisher test pvalue:
#     0.00000118
# start chi2 test
#   observed:
#     27.0000    2390.0000
#     673.0000    179954.0000
#   expected:
#     9.2431    2407.7569
#     690.7569    179936.2431
#   chi2: 32.7749
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     27.0000    2390.0000
#     673.0000    179954.0000
#   oddsratio: 3.0207
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 74689
# --> Not Suspect ICD Code: 56031
# --> Not Suspect ICD Code: H6090
# --> Not Suspect ICD Code: I69365
# --> Not Suspect ICD Code: M25472
# --> Not Suspect ICD Code: 5568
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     117.0000    2300.0000
#     117.0000    180510.0000
#   expected:
#     3.0898    2413.9102
#     230.9102    180396.0898
#   chi2: 4223.7212
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     117.0000    2300.0000
#     117.0000    180510.0000
#   oddsratio: 78.4826
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: L309
# --> Not Suspect ICD Code: N6481
# --> Not Suspect ICD Code: G652
# --> Not Suspect ICD Code: K011
# --> Not Suspect ICD Code: D869
# --> Not Suspect ICD Code: T84033A
# --> Not Suspect ICD Code: 35922
# --> Not Suspect ICD Code: 63592
# --> Not Suspect ICD Code: T826XXA
# --> Not Suspect ICD Code: S31502A
# --> Not Suspect ICD Code: 71913
# --> Not Suspect ICD Code: V1029
# --> Not Suspect ICD Code: 37520
# --> Not Suspect ICD Code: S26021A
# --> Not Suspect ICD Code: K6281
# --> Not Suspect ICD Code: F309
# --> Not Suspect ICD Code: 85121
# --> Not Suspect ICD Code: 9878
# --> Not Suspect ICD Code: 73390
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     134.0000    2283.0000
#     2659.0000    177968.0000
#   expected:
#     36.8801    2380.1199
#     2756.1199    177870.8801
#   chi2: 260.4904
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     134.0000    2283.0000
#     2659.0000    177968.0000
#   oddsratio: 3.9285
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 460
# --> Not Suspect ICD Code: M96843
# --> Not Suspect ICD Code: O99210
# --> Not Suspect ICD Code: 86501
# --> Not Suspect ICD Code: S14123S
# --> Not Suspect ICD Code: G513
# --> Not Suspect ICD Code: N262
# --> Not Suspect ICD Code: K209
# --> Not Suspect ICD Code: O2343
# --> Not Suspect ICD Code: 71221
# --> Not Suspect ICD Code: 45351
#   chi2 test pvalue:
#     0.00267461
#   fisher test pvalue:
#     0.00603284
# start chi2 test
#   observed:
#     7.0000    2410.0000
#     155.0000    180472.0000
#   expected:
#     2.1391    2414.8609
#     159.8609    180467.1391
#   chi2: 9.0171
#   pvalue: 0.0027
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     7.0000    2410.0000
#     155.0000    180472.0000
#   oddsratio: 3.3819
#   pvalue: 0.0060
# done.
# --> Not Suspect ICD Code: C050
# --> Not Suspect ICD Code: I76
# --> Not Suspect ICD Code: 7873
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000024
# start chi2 test
#   observed:
#     21.0000    2396.0000
#     393.0000    180234.0000
#   expected:
#     5.4667    2411.5333
#     408.5333    180218.4667
#   chi2: 41.9900
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     21.0000    2396.0000
#     393.0000    180234.0000
#   oddsratio: 4.0195
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: Z731
# --> Not Suspect ICD Code: V608
# --> Not Suspect ICD Code: H25019
# --> Not Suspect ICD Code: 34201
# --> Not Suspect ICD Code: O771
# --> Not Suspect ICD Code: 7242
#   chi2 test pvalue:
#     0.00023684
#   fisher test pvalue:
#     0.00043907
# start chi2 test
#   observed:
#     77.0000    2340.0000
#     3767.0000    176860.0000
#   expected:
#     50.7580    2366.2420
#     3793.2420    176833.7580
#   chi2: 13.5136
#   pvalue: 0.0002
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     77.0000    2340.0000
#     3767.0000    176860.0000
#   oddsratio: 1.5449
#   pvalue: 0.0004
# done.
# --> Not Suspect ICD Code: E0152
# --> Not Suspect ICD Code: C689
# --> Not Suspect ICD Code: 5360
# --> Not Suspect ICD Code: E9468
# --> Not Suspect ICD Code: F19980
# --> Not Suspect ICD Code: R770
# --> Not Suspect ICD Code: O9962
#   chi2 test pvalue:
#     0.00000344
#   fisher test pvalue:
#     0.00010244
# start chi2 test
#   observed:
#     13.0000    2404.0000
#     265.0000    180362.0000
#   expected:
#     3.6708    2413.3292
#     274.3292    180352.6708
#   chi2: 21.5529
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     13.0000    2404.0000
#     265.0000    180362.0000
#   oddsratio: 3.6805
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: Z9079
# --> Not Suspect ICD Code: 3575
# --> Not Suspect ICD Code: N451
# --> Not Suspect ICD Code: W69XXXA
# --> Not Suspect ICD Code: Z96653
# --> Not Suspect ICD Code: E530
# --> Not Suspect ICD Code: 6268
# --> Not Suspect ICD Code: 65511
# --> Not Suspect ICD Code: D644
# --> Not Suspect ICD Code: S24109A
# --> Not Suspect ICD Code: I8501
# --> Not Suspect ICD Code: S02641A
# --> Not Suspect ICD Code: 37214
# --> Not Suspect ICD Code: W298XXS
# --> Not Suspect ICD Code: A6923
# --> Not Suspect ICD Code: F1096
# --> Not Suspect ICD Code: O722
# --> Not Suspect ICD Code: 80025
# --> Not Suspect ICD Code: V528
# --> Not Suspect ICD Code: T494X5A
# --> Not Suspect ICD Code: I6980
# --> Not Suspect ICD Code: 65201
# --> Not Suspect ICD Code: S32010S
# --> Not Suspect ICD Code: S72452K
# --> Not Suspect ICD Code: L859
# --> Not Suspect ICD Code: C9111
# --> Not Suspect ICD Code: Z4589
# --> Not Suspect ICD Code: Z86005
# --> Not Suspect ICD Code: 72931
# --> Not Suspect ICD Code: Z853
# --> Not Suspect ICD Code: R2231
# --> Not Suspect ICD Code: S22069A
# --> Not Suspect ICD Code: 59010
#   chi2 test pvalue:
#     0.00088034
#   fisher test pvalue:
#     0.00194756
# start chi2 test
#   observed:
#     18.0000    2399.0000
#     596.0000    180031.0000
#   expected:
#     8.1075    2408.8925
#     605.8925    180021.1075
#   chi2: 11.0637
#   pvalue: 0.0009
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     18.0000    2399.0000
#     596.0000    180031.0000
#   oddsratio: 2.2664
#   pvalue: 0.0019
# done.
# --> Not Suspect ICD Code: T1491XA
# --> Not Suspect ICD Code: 7856
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     51.0000    2366.0000
#     1103.0000    179524.0000
#   expected:
#     15.2380    2401.7620
#     1138.7620    179488.2380
#   chi2: 83.2161
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     51.0000    2366.0000
#     1103.0000    179524.0000
#   oddsratio: 3.5083
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 53784
# --> Not Suspect ICD Code: H8110
# --> Not Suspect ICD Code: 7429
# --> Not Suspect ICD Code: F3281
# --> Not Suspect ICD Code: M96811
# --> Not Suspect ICD Code: 2825
# --> Not Suspect ICD Code: 71512
# --> Not Suspect ICD Code: S12430A
# --> Not Suspect ICD Code: C8170
# --> Not Suspect ICD Code: I742
# --> Not Suspect ICD Code: Z85238
# --> Not Suspect ICD Code: S27491A
# --> Not Suspect ICD Code: S72101A
# --> Not Suspect ICD Code: S2220XS
# --> Not Suspect ICD Code: S72401D
# --> Not Suspect ICD Code: 34510
# --> Not Suspect ICD Code: 9031
# --> Not Suspect ICD Code: S5431XA
# --> Not Suspect ICD Code: 74869
# --> Not Suspect ICD Code: G7119
# --> Not Suspect ICD Code: S72411K
# --> Not Suspect ICD Code: V4551
# --> Not Suspect ICD Code: 5277
# --> Not Suspect ICD Code: 71504
# --> Not Suspect ICD Code: Y92129
# --> Not Suspect ICD Code: M84671A
# --> Not Suspect ICD Code: I629
# --> Not Suspect ICD Code: K591
# --> Not Suspect ICD Code: 74320
# --> Not Suspect ICD Code: 72883
# --> Not Suspect ICD Code: Q969
# --> Not Suspect ICD Code: S62614A
# --> Not Suspect ICD Code: N5201
# --> Not Suspect ICD Code: M71561
# --> Not Suspect ICD Code: S62327A
# --> Not Suspect ICD Code: S06341A
# --> Not Suspect ICD Code: C3432
# --> Not Suspect ICD Code: 9157
# --> Not Suspect ICD Code: V4586
# --> Not Suspect ICD Code: S21132A
# --> Not Suspect ICD Code: C109
# --> Not Suspect ICD Code: 9753
# --> Not Suspect ICD Code: 80234
# --> Not Suspect ICD Code: T43636A
# --> Not Suspect ICD Code: S22059D
# --> Not Suspect ICD Code: 36030
# --> Not Suspect ICD Code: M5106
# --> Not Suspect ICD Code: 57421
# --> Not Suspect ICD Code: H30891
# --> Not Suspect ICD Code: 9221
# --> Not Suspect ICD Code: S42392A
# --> Not Suspect ICD Code: O88312
# --> Not Suspect ICD Code: T45511A
# --> Not Suspect ICD Code: R008
# --> Not Suspect ICD Code: S0542XA
# --> Not Suspect ICD Code: S8255XA
# --> Not Suspect ICD Code: 5679
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000525
# start chi2 test
#   observed:
#     13.0000    2404.0000
#     196.0000    180431.0000
#   expected:
#     2.7597    2414.2403
#     206.2403    180420.7597
#   chi2: 34.8773
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     13.0000    2404.0000
#     196.0000    180431.0000
#   oddsratio: 4.9781
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 72740
# --> Not Suspect ICD Code: S42302A
# --> Not Suspect ICD Code: G910
# --> Not Suspect ICD Code: S31105D
# --> Not Suspect ICD Code: S42252A
# --> Not Suspect ICD Code: S92235A
# --> Not Suspect ICD Code: O43232
# --> Not Suspect ICD Code: T83012A
# --> Not Suspect ICD Code: 8470
# --> Not Suspect ICD Code: L97818
# --> Not Suspect ICD Code: M85842
# --> Not Suspect ICD Code: 8460
# --> Not Suspect ICD Code: 81411
# --> Not Suspect ICD Code: S42002A
# --> Not Suspect ICD Code: T84623A
# --> Not Suspect ICD Code: L03032
# --> Not Suspect ICD Code: V6403
# --> Not Suspect ICD Code: F4311
# --> Not Suspect ICD Code: M216X9
# --> Not Suspect ICD Code: M1009
# --> Not Suspect ICD Code: 57481
# --> Not Suspect ICD Code: 566
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     81.0000    2336.0000
#     291.0000    180336.0000
#   expected:
#     4.9121    2412.0879
#     367.0879    180259.9121
#   chi2: 1181.1287
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     81.0000    2336.0000
#     291.0000    180336.0000
#   oddsratio: 21.4883
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 73329
# --> Not Suspect ICD Code: I611
# --> Not Suspect ICD Code: 30750
# --> Not Suspect ICD Code: G301
# --> Not Suspect ICD Code: Z89422
# --> Not Suspect ICD Code: S22020A
# --> Not Suspect ICD Code: 37052
# --> Not Suspect ICD Code: 6018
# --> Not Suspect ICD Code: M87151
# --> Not Suspect ICD Code: 7241
# --> Not Suspect ICD Code: 37652
# --> Not Suspect ICD Code: 81000
# --> Not Suspect ICD Code: 45621
#   chi2 test pvalue:
#     0.00000056
#   fisher test pvalue:
#     0.00000876
# start chi2 test
#   observed:
#     33.0000    2384.0000
#     1025.0000    179602.0000
#   expected:
#     13.9703    2403.0297
#     1044.0297    179582.9703
#   chi2: 25.0506
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     33.0000    2384.0000
#     1025.0000    179602.0000
#   oddsratio: 2.4255
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: S42109A
# --> Not Suspect ICD Code: J90
# --> Not Suspect ICD Code: F1219
# --> Not Suspect ICD Code: S62211A
# --> Not Suspect ICD Code: V4792XA
# --> Not Suspect ICD Code: G131
# --> Not Suspect ICD Code: 9563
# --> Not Suspect ICD Code: O2231
# --> Not Suspect ICD Code: S27391A
# --> Not Suspect ICD Code: 80223
# --> Not Suspect ICD Code: S4292XA
# --> Not Suspect ICD Code: D241
# --> Not Suspect ICD Code: T361X6A
# --> Not Suspect ICD Code: V1529
# --> Not Suspect ICD Code: M26609
# --> Not Suspect ICD Code: D531
# --> Not Suspect ICD Code: 9560
# --> Not Suspect ICD Code: N99842
# --> Not Suspect ICD Code: Z9149
# --> Not Suspect ICD Code: 1966
# --> Not Suspect ICD Code: T23121A
# --> Not Suspect ICD Code: H8120
# --> Not Suspect ICD Code: 83901
# --> Not Suspect ICD Code: K838
# --> Not Suspect ICD Code: 5291
# --> Not Suspect ICD Code: R440
# --> Not Suspect ICD Code: S90112A
# --> Not Suspect ICD Code: L89896
# --> Not Suspect ICD Code: M62412
# --> Not Suspect ICD Code: 72789
# --> Not Suspect ICD Code: C251
# --> Not Suspect ICD Code: Y908
# --> Not Suspect ICD Code: 25071
# --> Not Suspect ICD Code: Y92511
# --> Not Suspect ICD Code: N610
# --> Not Suspect ICD Code: 20921
# --> Not Suspect ICD Code: 53649
# --> Not Suspect ICD Code: C8522
# --> Not Suspect ICD Code: K55059
# --> Not Suspect ICD Code: C44792
# --> Not Suspect ICD Code: S65091A
# --> Not Suspect ICD Code: M10042
# --> Not Suspect ICD Code: M71042
# --> Not Suspect ICD Code: 3019
#   chi2 test pvalue:
#     0.00719249
#   fisher test pvalue:
#     0.00991681
# start chi2 test
#   observed:
#     8.0000    2409.0000
#     214.0000    180413.0000
#   expected:
#     2.9314    2414.0686
#     219.0686    180407.9314
#   chi2: 7.2243
#   pvalue: 0.0072
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     8.0000    2409.0000
#     214.0000    180413.0000
#   oddsratio: 2.7997
#   pvalue: 0.0099
# done.
# --> Not Suspect ICD Code: H0220C
# --> Not Suspect ICD Code: 3360
# --> Not Suspect ICD Code: 1129
#   chi2 test pvalue:
#     0.00182083
#   fisher test pvalue:
#     0.00634276
# start chi2 test
#   observed:
#     5.0000    2412.0000
#     83.0000    180544.0000
#   expected:
#     1.1620    2415.8380
#     86.8380    180540.1620
#   chi2: 9.7219
#   pvalue: 0.0018
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     5.0000    2412.0000
#     83.0000    180544.0000
#   oddsratio: 4.5092
#   pvalue: 0.0063
# done.
# --> Not Suspect ICD Code: O00102
# --> Not Suspect ICD Code: S2769XA
# --> Not Suspect ICD Code: F911
# --> Not Suspect ICD Code: N141
# --> Not Suspect ICD Code: I6503
# --> Not Suspect ICD Code: S6722XA
# --> Not Suspect ICD Code: E8609
# --> Not Suspect ICD Code: S3739XA
# --> Not Suspect ICD Code: H353110
# --> Not Suspect ICD Code: 62401
# --> Not Suspect ICD Code: 57420
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     54.0000    2363.0000
#     1420.0000    179207.0000
#   expected:
#     19.4634    2397.5366
#     1454.5366    179172.4634
#   chi2: 60.8076
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     54.0000    2363.0000
#     1420.0000    179207.0000
#   oddsratio: 2.8840
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 01485
# --> Not Suspect ICD Code: A049
# --> Not Suspect ICD Code: 29645
# --> Not Suspect ICD Code: E640
# --> Not Suspect ICD Code: H59091
# --> Not Suspect ICD Code: 8400
# --> Not Suspect ICD Code: C323
# --> Not Suspect ICD Code: 71667
# --> Not Suspect ICD Code: C7962
# --> Not Suspect ICD Code: Y35001S
# --> Not Suspect ICD Code: S92002B
# --> Not Suspect ICD Code: 65491
# --> Not Suspect ICD Code: M05612
# --> Not Suspect ICD Code: 78605
# --> Not Suspect ICD Code: R402341
# --> Not Suspect ICD Code: S90421A
# --> Not Suspect ICD Code: M8978
# --> Not Suspect ICD Code: L816
# --> Not Suspect ICD Code: 66411
# --> Not Suspect ICD Code: 36616
# --> Not Suspect ICD Code: G5732
# --> Not Suspect ICD Code: N008
# --> Not Suspect ICD Code: V5489
# --> Not Suspect ICD Code: H47399
# --> Not Suspect ICD Code: V440
# --> Not Suspect ICD Code: 7101
#   chi2 test pvalue:
#     0.00041148
#   fisher test pvalue:
#     0.00203709
# start chi2 test
#   observed:
#     8.0000    2409.0000
#     162.0000    180465.0000
#   expected:
#     2.2448    2414.7552
#     167.7552    180459.2448
#   chi2: 12.4793
#   pvalue: 0.0004
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     8.0000    2409.0000
#     162.0000    180465.0000
#   oddsratio: 3.6994
#   pvalue: 0.0020
# done.
# --> Not Suspect ICD Code: 94311
# --> Not Suspect ICD Code: E0069
# --> Not Suspect ICD Code: 35801
# --> Not Suspect ICD Code: E9670
# --> Not Suspect ICD Code: S41111A
# --> Not Suspect ICD Code: J1000
# --> Not Suspect ICD Code: T80219A
# --> Not Suspect ICD Code: 486
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     225.0000    2192.0000
#     8547.0000    172080.0000
#   expected:
#     115.8297    2301.1703
#     8656.1703    171970.8297
#   chi2: 108.5183
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     225.0000    2192.0000
#     8547.0000    172080.0000
#   oddsratio: 2.0666
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: S83522A
# --> Not Suspect ICD Code: 3108
# --> Not Suspect ICD Code: E9029
# --> Not Suspect ICD Code: 63490
# --> Not Suspect ICD Code: 4162
#   chi2 test pvalue:
#     0.00208720
#   fisher test pvalue:
#     0.00416280
# start chi2 test
#   observed:
#     10.0000    2407.0000
#     267.0000    180360.0000
#   expected:
#     3.6576    2413.3424
#     273.3424    180353.6576
#   chi2: 9.4712
#   pvalue: 0.0021
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     10.0000    2407.0000
#     267.0000    180360.0000
#   oddsratio: 2.8064
#   pvalue: 0.0042
# done.
# --> Not Suspect ICD Code: O9202
# --> Not Suspect ICD Code: J1529
# --> Not Suspect ICD Code: O0902
# --> Not Suspect ICD Code: S9304XA
# --> Not Suspect ICD Code: T39011A
# --> Not Suspect ICD Code: 2379
# --> Not Suspect ICD Code: D165
# --> Not Suspect ICD Code: 7312
# --> Not Suspect ICD Code: 00869
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     18.0000    2399.0000
#     61.0000    180566.0000
#   expected:
#     1.0432    2415.9568
#     77.9568    180549.0432
#   chi2: 263.2118
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     18.0000    2399.0000
#     61.0000    180566.0000
#   oddsratio: 22.2100
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 86803
# --> Not Suspect ICD Code: K449
# --> Not Suspect ICD Code: 4572
# --> Not Suspect ICD Code: V619
# --> Not Suspect ICD Code: E8192
# --> Not Suspect ICD Code: S89192D
# --> Not Suspect ICD Code: E860
#   chi2 test pvalue:
#     0.00002038
#   fisher test pvalue:
#     0.00004982
# start chi2 test
#   observed:
#     97.0000    2320.0000
#     4695.0000    175932.0000
#   expected:
#     63.2758    2353.7242
#     4728.7242    175898.2758
#   chi2: 18.1536
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     97.0000    2320.0000
#     4695.0000    175932.0000
#   oddsratio: 1.5667
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: V582
# --> Not Suspect ICD Code: 59789
# --> Not Suspect ICD Code: 65141
# --> Not Suspect ICD Code: M26221
# --> Not Suspect ICD Code: R4587
# --> Not Suspect ICD Code: H25813
# --> Not Suspect ICD Code: T82590A
# --> Not Suspect ICD Code: S82431B
# --> Not Suspect ICD Code: S32029A
# --> Not Suspect ICD Code: 75569
# --> Not Suspect ICD Code: S92344D
# --> Not Suspect ICD Code: L709
# --> Not Suspect ICD Code: H53459
# --> Not Suspect ICD Code: T84012A
# --> Not Suspect ICD Code: E976
# --> Not Suspect ICD Code: 80012
# --> Not Suspect ICD Code: S32311A
# --> Not Suspect ICD Code: 74763
# --> Not Suspect ICD Code: M79603
# --> Not Suspect ICD Code: 75430
# --> Not Suspect ICD Code: D044
# --> Not Suspect ICD Code: H7090
# --> Not Suspect ICD Code: Q396
# --> Not Suspect ICD Code: 83301
# --> Not Suspect ICD Code: V153
#   chi2 test pvalue:
#     0.00000130
#   fisher test pvalue:
#     0.00000621
# start chi2 test
#   observed:
#     79.0000    2338.0000
#     3416.0000    177211.0000
#   expected:
#     46.1496    2370.8504
#     3448.8504    177178.1496
#   chi2: 23.4280
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     79.0000    2338.0000
#     3416.0000    177211.0000
#   oddsratio: 1.7529
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: C8373
# --> Not Suspect ICD Code: W182XXD
# --> Not Suspect ICD Code: Z825
# --> Not Suspect ICD Code: S92121B
# --> Not Suspect ICD Code: 53130
# --> Not Suspect ICD Code: 7946
# --> Not Suspect ICD Code: 3369
# --> Not Suspect ICD Code: D749
# --> Not Suspect ICD Code: 2819
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     39.0000    2378.0000
#     884.0000    179743.0000
#   expected:
#     12.1877    2404.8123
#     910.8123    179716.1877
#   chi2: 57.8578
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     39.0000    2378.0000
#     884.0000    179743.0000
#   oddsratio: 3.3347
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: N7689
# --> Not Suspect ICD Code: 80336
# --> Not Suspect ICD Code: 64612
# --> Not Suspect ICD Code: 56981
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     108.0000    2309.0000
#     313.0000    180314.0000
#   expected:
#     5.5591    2411.4409
#     415.4409    180211.5591
#   chi2: 1898.7451
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     108.0000    2309.0000
#     313.0000    180314.0000
#   oddsratio: 26.9454
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: M11232
# --> Not Suspect ICD Code: V8699XD
# --> Not Suspect ICD Code: M7731
# --> Not Suspect ICD Code: O99810
# --> Not Suspect ICD Code: G008
# --> Not Suspect ICD Code: V4589
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     156.0000    2261.0000
#     3811.0000    176816.0000
#   expected:
#     52.3822    2364.6178
#     3914.6178    176712.3822
#   chi2: 210.2678
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     156.0000    2261.0000
#     3811.0000    176816.0000
#   oddsratio: 3.2012
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: L97426
# --> Not Suspect ICD Code: 64631
# --> Not Suspect ICD Code: Z8262
# --> Not Suspect ICD Code: Z4902
# --> Not Suspect ICD Code: R0602
# --> Not Suspect ICD Code: O30103
# --> Not Suspect ICD Code: 85209
# --> Not Suspect ICD Code: 20200
# --> Not Suspect ICD Code: 4919
#   chi2 test pvalue:
#     0.00007516
#   fisher test pvalue:
#     0.00107678
# start chi2 test
#   observed:
#     7.0000    2410.0000
#     112.0000    180515.0000
#   expected:
#     1.5713    2415.4287
#     117.4287    180509.5713
#   chi2: 15.6764
#   pvalue: 0.0001
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     7.0000    2410.0000
#     112.0000    180515.0000
#   oddsratio: 4.6814
#   pvalue: 0.0011
# done.
# --> Not Suspect ICD Code: V1585
# --> Not Suspect ICD Code: 2442
# --> Not Suspect ICD Code: V4611
# --> Not Suspect ICD Code: V244XXA
# --> Not Suspect ICD Code: Q111
# --> Not Suspect ICD Code: K266
# --> Not Suspect ICD Code: 72661
# --> Not Suspect ICD Code: S42202A
# --> Not Suspect ICD Code: 6288
# --> Not Suspect ICD Code: Z8781
# --> Not Suspect ICD Code: O872
# --> Not Suspect ICD Code: E063
# --> Not Suspect ICD Code: C383
# --> Not Suspect ICD Code: Y728
# --> Not Suspect ICD Code: 64711
# --> Not Suspect ICD Code: H93232
# --> Not Suspect ICD Code: 73343
# --> Not Suspect ICD Code: S35298A
# --> Not Suspect ICD Code: I69831
# --> Not Suspect ICD Code: E0080
# --> Not Suspect ICD Code: S13140A
# --> Not Suspect ICD Code: 37854
# --> Not Suspect ICD Code: 6178
# --> Not Suspect ICD Code: H0231
# --> Not Suspect ICD Code: E859
# --> Not Suspect ICD Code: 55000
# --> Not Suspect ICD Code: L291
# --> Not Suspect ICD Code: S42392P
# --> Not Suspect ICD Code: S14127A
# --> Not Suspect ICD Code: 6210
# --> Not Suspect ICD Code: I70522
# --> Not Suspect ICD Code: O00111
# --> Not Suspect ICD Code: F2089
# --> Not Suspect ICD Code: 20008
# --> Not Suspect ICD Code: M25811
# --> Not Suspect ICD Code: Z8279
# --> Not Suspect ICD Code: D487
# --> Not Suspect ICD Code: M532X4
# --> Not Suspect ICD Code: 5178
# --> Not Suspect ICD Code: T8249XA
# --> Not Suspect ICD Code: 41405
# --> Not Suspect ICD Code: S42035A
# --> Not Suspect ICD Code: D1039
# --> Not Suspect ICD Code: O9229
# --> Not Suspect ICD Code: J930
# --> Not Suspect ICD Code: I972
# --> Not Suspect ICD Code: 69552
# --> Not Suspect ICD Code: I821
# --> Not Suspect ICD Code: 86389
# --> Not Suspect ICD Code: 36720
# --> Not Suspect ICD Code: Y93H1
# --> Not Suspect ICD Code: M65151
# --> Not Suspect ICD Code: R10826
# --> Not Suspect ICD Code: F4310
# --> Not Suspect ICD Code: O24313
# --> Not Suspect ICD Code: V299XXD
# --> Not Suspect ICD Code: J95859
# --> Not Suspect ICD Code: V270XXA
# --> Not Suspect ICD Code: 501
# --> Not Suspect ICD Code: N171
# --> Not Suspect ICD Code: E916
# --> Not Suspect ICD Code: O902
# --> Not Suspect ICD Code: O34592
# --> Not Suspect ICD Code: I426
# --> Not Suspect ICD Code: S85171A
# --> Not Suspect ICD Code: I82291
# --> Not Suspect ICD Code: Y834
# --> Not Suspect ICD Code: 20043
# --> Not Suspect ICD Code: V5866
#   chi2 test pvalue:
#     0.00004264
#   fisher test pvalue:
#     0.00007240
# start chi2 test
#   observed:
#     182.0000    2235.0000
#     10081.0000    170546.0000
#   expected:
#     135.5175    2281.4825
#     10127.4825    170499.5175
#   chi2: 16.7503
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     182.0000    2235.0000
#     10081.0000    170546.0000
#   oddsratio: 1.3776
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: 4239
# --> Not Suspect ICD Code: S069X1S
# --> Not Suspect ICD Code: 72400
# --> Not Suspect ICD Code: T2101XA
# --> Not Suspect ICD Code: S8265XA
# --> Not Suspect ICD Code: 1638
# --> Not Suspect ICD Code: C9421
# --> Not Suspect ICD Code: V596
# --> Not Suspect ICD Code: 36644
# --> Not Suspect ICD Code: L97211
# --> Not Suspect ICD Code: 87411
# --> Not Suspect ICD Code: 59972
#   chi2 test pvalue:
#     0.00000021
#   fisher test pvalue:
#     0.00001241
# start chi2 test
#   observed:
#     19.0000    2398.0000
#     431.0000    180196.0000
#   expected:
#     5.9420    2411.0580
#     444.0580    180182.9420
#   chi2: 26.9618
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     19.0000    2398.0000
#     431.0000    180196.0000
#   oddsratio: 3.3126
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 3062
# --> Not Suspect ICD Code: T43505A
# --> Not Suspect ICD Code: M2391
# --> Not Suspect ICD Code: K2960
# --> Not Suspect ICD Code: T18128A
# --> Not Suspect ICD Code: T24102A
# --> Not Suspect ICD Code: M4710
# --> Not Suspect ICD Code: 64101
# --> Not Suspect ICD Code: 0362
# --> Not Suspect ICD Code: M65171
# --> Not Suspect ICD Code: 5194
# --> Not Suspect ICD Code: E0109
# --> Not Suspect ICD Code: S4291XD
# --> Not Suspect ICD Code: Y792
# --> Not Suspect ICD Code: E668
# --> Not Suspect ICD Code: O1405
# --> Not Suspect ICD Code: S32042A
# --> Not Suspect ICD Code: 00843
#   chi2 test pvalue:
#     0.00376539
#   fisher test pvalue:
#     0.01279146
# start chi2 test
#   observed:
#     3.0000    2414.0000
#     34.0000    180593.0000
#   expected:
#     0.4886    2416.5114
#     36.5114    180590.4886
#   chi2: 8.3936
#   pvalue: 0.0038
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     3.0000    2414.0000
#     34.0000    180593.0000
#   oddsratio: 6.6009
#   pvalue: 0.0128
# done.
# --> Not Suspect ICD Code: K91870
# --> Not Suspect ICD Code: S058X2S
# --> Not Suspect ICD Code: 34590
#   chi2 test pvalue:
#     0.00004476
#   fisher test pvalue:
#     0.00012947
# start chi2 test
#   observed:
#     72.0000    2345.0000
#     3310.0000    177317.0000
#   expected:
#     44.6575    2372.3425
#     3337.3425    177289.6575
#   chi2: 16.6580
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     72.0000    2345.0000
#     3310.0000    177317.0000
#   oddsratio: 1.6448
#   pvalue: 0.0001
# done.
# --> Not Suspect ICD Code: T23202A
# --> Not Suspect ICD Code: S72102A
# --> Not Suspect ICD Code: Z7251
# --> Not Suspect ICD Code: E8796
#   chi2 test pvalue:
#     0.00049848
#   fisher test pvalue:
#     0.00103997
# start chi2 test
#   observed:
#     24.0000    2393.0000
#     862.0000    179765.0000
#   expected:
#     11.6992    2405.3008
#     874.3008    179752.6992
#   chi2: 12.1213
#   pvalue: 0.0005
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     24.0000    2393.0000
#     862.0000    179765.0000
#   oddsratio: 2.0915
#   pvalue: 0.0010
# done.
# --> Not Suspect ICD Code: N83521
# --> Not Suspect ICD Code: Y92513
# --> Not Suspect ICD Code: O4592
# --> Not Suspect ICD Code: D3617
# --> Not Suspect ICD Code: N83209
# --> Not Suspect ICD Code: 9152
# --> Not Suspect ICD Code: S0122XA
# --> Not Suspect ICD Code: 75261
# --> Not Suspect ICD Code: Z3A22
# --> Not Suspect ICD Code: Y782
# --> Not Suspect ICD Code: S99922A
# --> Not Suspect ICD Code: 31539
# --> Not Suspect ICD Code: W1789XA
# --> Not Suspect ICD Code: V375XXA
# --> Not Suspect ICD Code: K651
#   chi2 test pvalue:
#     0.00000229
#   fisher test pvalue:
#     0.00004824
# start chi2 test
#   observed:
#     18.0000    2399.0000
#     437.0000    180190.0000
#   expected:
#     6.0080    2410.9920
#     448.9920    180178.0080
#   chi2: 22.3311
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     18.0000    2399.0000
#     437.0000    180190.0000
#   oddsratio: 3.0938
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 33904
# --> Not Suspect ICD Code: 32301
# --> Not Suspect ICD Code: 27652
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     181.0000    2236.0000
#     3865.0000    176762.0000
#   expected:
#     53.4253    2363.5747
#     3992.5747    176634.4253
#   chi2: 313.2213
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     181.0000    2236.0000
#     3865.0000    176762.0000
#   oddsratio: 3.7021
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 4460
# --> Not Suspect ICD Code: 86812
# --> Not Suspect ICD Code: K739
# --> Not Suspect ICD Code: V1252
#   chi2 test pvalue:
#     0.00004195
#   fisher test pvalue:
#     0.00138666
# start chi2 test
#   observed:
#     5.0000    2412.0000
#     57.0000    180570.0000
#   expected:
#     0.8187    2416.1813
#     61.1813    180565.8187
#   chi2: 16.7809
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     5.0000    2412.0000
#     57.0000    180570.0000
#   oddsratio: 6.5669
#   pvalue: 0.0014
# done.
# --> Not Suspect ICD Code: Z85828
# --> Not Suspect ICD Code: 71942
# --> Not Suspect ICD Code: J381
# --> Not Suspect ICD Code: S9031XS
# --> Not Suspect ICD Code: J1181
# --> Not Suspect ICD Code: S0269XA
# --> Not Suspect ICD Code: Z89621
# --> Not Suspect ICD Code: 38103
# --> Not Suspect ICD Code: T434X5D
# --> Not Suspect ICD Code: L928
# --> Not Suspect ICD Code: E969
# --> Not Suspect ICD Code: 650
# --> Not Suspect ICD Code: O690XX1
# --> Not Suspect ICD Code: M4690
# --> Not Suspect ICD Code: 3071
# --> Not Suspect ICD Code: D538
# --> Not Suspect ICD Code: G231
# --> Not Suspect ICD Code: Z6829
# --> Not Suspect ICD Code: S46122A
# --> Not Suspect ICD Code: S3289XA
# --> Not Suspect ICD Code: 7910
# --> Not Suspect ICD Code: M6240
# --> Not Suspect ICD Code: I672
# --> Not Suspect ICD Code: V4039
# --> Not Suspect ICD Code: 38914
# --> Not Suspect ICD Code: M5117
# --> Not Suspect ICD Code: E8242
# --> Not Suspect ICD Code: E248
# --> Not Suspect ICD Code: Y92411
# --> Not Suspect ICD Code: M1652
# ...
# --> Not Suspect ICD Code: M19049
# --> Not Suspect ICD Code: S82842D
# --> Not Suspect ICD Code: 937
# --> Not Suspect ICD Code: 73729
# --> Not Suspect ICD Code: 37405
# --> Not Suspect ICD Code: 38611
# --> Not Suspect ICD Code: V4512
# --> Not Suspect ICD Code: H2703
# --> Not Suspect ICD Code: S62313B
# --> Not Suspect ICD Code: 36974
# --> Not Suspect ICD Code: 3334
# --> Not Suspect ICD Code: M2390
# --> Not Suspect ICD Code: E8981
# --> Not Suspect ICD Code: Z0389
# --> Not Suspect ICD Code: S63501D
# --> Not Suspect ICD Code: K5909
# --> Not Suspect ICD Code: H401194
# --> Not Suspect ICD Code: D528
# --> Not Suspect ICD Code: 7558
# --> Not Suspect ICD Code: I82A11
# --> Not Suspect ICD Code: R402313
# --> Not Suspect ICD Code: N99528
# --> Not Suspect ICD Code: 67144
# --> Not Suspect ICD Code: D7581
#   chi2 test pvalue:
#     0.00000296
#   fisher test pvalue:
#     0.00091426
# start chi2 test
#   observed:
#     4.0000    2413.0000
#     29.0000    180598.0000
#   expected:
#     0.4357    2416.5643
#     32.5643    180594.4357
#   chi2: 21.8406
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     4.0000    2413.0000
#     29.0000    180598.0000
#   oddsratio: 10.3233
#   pvalue: 0.0009
# done.
# --> Not Suspect ICD Code: E8368
# --> Not Suspect ICD Code: T8351XA
# --> Not Suspect ICD Code: I319
# --> Not Suspect ICD Code: S82452B
# --> Not Suspect ICD Code: T17498A
# --> Not Suspect ICD Code: S058X2D
# --> Not Suspect ICD Code: 37006
# --> Not Suspect ICD Code: M2062
# --> Not Suspect ICD Code: G47419
# --> Not Suspect ICD Code: 6080
# --> Not Suspect ICD Code: C8281
# --> Not Suspect ICD Code: C761
# --> Not Suspect ICD Code: M3313
# --> Not Suspect ICD Code: S00532A
# --> Not Suspect ICD Code: M0820
# --> Not Suspect ICD Code: C8440
# --> Not Suspect ICD Code: S22088S
# --> Not Suspect ICD Code: 7245
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     111.0000    2306.0000
#     3999.0000    176628.0000
#   expected:
#     54.2704    2362.7296
#     4055.7296    176571.2704
#   chi2: 60.3952
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     111.0000    2306.0000
#     3999.0000    176628.0000
#   oddsratio: 2.1260
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: S27892A
# --> Not Suspect ICD Code: R311
# --> Not Suspect ICD Code: F449
# --> Not Suspect ICD Code: V6400
# --> Not Suspect ICD Code: D4410
# --> Not Suspect ICD Code: R402243
# --> Not Suspect ICD Code: E8715
# --> Not Suspect ICD Code: 6802
# --> Not Suspect ICD Code: 8728
# --> Not Suspect ICD Code: S90822A
# --> Not Suspect ICD Code: I83222
# --> Not Suspect ICD Code: 3314
#   chi2 test pvalue:
#     0.01051121
#   fisher test pvalue:
#     0.00218586
# start chi2 test
#   observed:
#     1.0000    2416.0000
#     695.0000    179932.0000
#   expected:
#     9.1903    2407.8097
#     686.8097    179940.1903
#   chi2: 6.5461
#   pvalue: 0.0105
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2416.0000
#     695.0000    179932.0000
#   oddsratio: 0.1072
#   pvalue: 0.0022
# done.
# --> Not Suspect ICD Code: 1838
# --> Not Suspect ICD Code: T24001D
# --> Not Suspect ICD Code: 72673
# --> Not Suspect ICD Code: 1910
# --> Not Suspect ICD Code: O324XX0
# --> Not Suspect ICD Code: 20252
# --> Not Suspect ICD Code: K276
# --> Not Suspect ICD Code: Z2914
# --> Not Suspect ICD Code: W3400XS
# --> Not Suspect ICD Code: Y92482
# --> Not Suspect ICD Code: S92332B
# --> Not Suspect ICD Code: Z3A29
# --> Not Suspect ICD Code: Y828
# --> Not Suspect ICD Code: 9671
# --> Not Suspect ICD Code: 9583
# --> Not Suspect ICD Code: 6806
# --> Not Suspect ICD Code: S62395A
# --> Not Suspect ICD Code: S62306D
# --> Not Suspect ICD Code: H35379
# --> Not Suspect ICD Code: S82192A
# --> Not Suspect ICD Code: S61001A
# --> Not Suspect ICD Code: S2221XA
# --> Not Suspect ICD Code: C7490
# --> Not Suspect ICD Code: S92251B
# --> Not Suspect ICD Code: S82852B
# --> Not Suspect ICD Code: 60020
# --> Not Suspect ICD Code: M84364K
# --> Not Suspect ICD Code: J4541
# --> Not Suspect ICD Code: O94
# --> Not Suspect ICD Code: 51882
# --> Not Suspect ICD Code: O9A212
# --> Not Suspect ICD Code: K5712
# --> Not Suspect ICD Code: M25612
# --> Not Suspect ICD Code: 65953
# --> Not Suspect ICD Code: G8104
# --> Not Suspect ICD Code: T423X1A
# --> Not Suspect ICD Code: T24002A
# --> Not Suspect ICD Code: M96671
# --> Not Suspect ICD Code: V4960XS
# --> Not Suspect ICD Code: Y288XXA
# --> Not Suspect ICD Code: I70409
# --> Not Suspect ICD Code: V0392XA
# --> Not Suspect ICD Code: K8001
# --> Not Suspect ICD Code: H33102
# --> Not Suspect ICD Code: M25831
# --> Not Suspect ICD Code: 99662
#   chi2 test pvalue:
#     0.00000000
#   fisher test pvalue:
#     0.00000000
# start chi2 test
#   observed:
#     28.0000    2389.0000
#     522.0000    180105.0000
#   expected:
#     7.2625    2409.7375
#     542.7375    180084.2625
#   chi2: 57.3207
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     28.0000    2389.0000
#     522.0000    180105.0000
#   oddsratio: 4.0439
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: S72034A
# --> Not Suspect ICD Code: S4982XA
# --> Not Suspect ICD Code: H5442A3
# --> Not Suspect ICD Code: 07888
# --> Not Suspect ICD Code: I69322
# --> Not Suspect ICD Code: 43400
#   chi2 test pvalue:
#     0.00914368
#   fisher test pvalue:
#     0.02317831
# start chi2 test
#   observed:
#     2.0000    2415.0000
#     16.0000    180611.0000
#   expected:
#     0.2377    2416.7623
#     17.7623    180609.2377
#   chi2: 6.7945
#   pvalue: 0.0091
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     2.0000    2415.0000
#     16.0000    180611.0000
#   oddsratio: 9.3484
#   pvalue: 0.0232
# done.
# --> Not Suspect ICD Code: L89310
# --> Not Suspect ICD Code: S42435A
# --> Not Suspect ICD Code: E8197
# --> Not Suspect ICD Code: E9211
# --> Not Suspect ICD Code: N13722
# --> Not Suspect ICD Code: 64233
#   chi2 test pvalue:
#     0.00622215
#   fisher test pvalue:
#     0.01160953
# start chi2 test
#   observed:
#     5.0000    2412.0000
#     97.0000    180530.0000
#   expected:
#     1.3469    2415.6531
#     100.6531    180526.3469
#   chi2: 7.4848
#   pvalue: 0.0062
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     5.0000    2412.0000
#     97.0000    180530.0000
#   oddsratio: 3.8581
#   pvalue: 0.0116
# done.
# --> Not Suspect ICD Code: S14116A
# --> Not Suspect ICD Code: Z022
# --> Not Suspect ICD Code: 20929
# --> Not Suspect ICD Code: 3202
# --> Not Suspect ICD Code: Z3A25
# --> Not Suspect ICD Code: E208
# --> Not Suspect ICD Code: T23211D
# --> Not Suspect ICD Code: F73
# --> Not Suspect ICD Code: T463X6A
# --> Not Suspect ICD Code: G90523
# --> Not Suspect ICD Code: 25043
# --> Not Suspect ICD Code: I688
# --> Not Suspect ICD Code: L97318
# --> Not Suspect ICD Code: V485XXA
# --> Not Suspect ICD Code: M76891
# --> Not Suspect ICD Code: 29530
# --> Not Suspect ICD Code: S3130XA
# --> Not Suspect ICD Code: 1809
# --> Not Suspect ICD Code: G713
# --> Not Suspect ICD Code: S65505A
# --> Not Suspect ICD Code: S062X9A
# --> Not Suspect ICD Code: 4464
#   chi2 test pvalue:
#     0.00002277
#   fisher test pvalue:
#     0.00083635
# start chi2 test
#   observed:
#     6.0000    2411.0000
#     77.0000    180550.0000
#   expected:
#     1.0960    2415.9040
#     81.9040    180545.0960
#   chi2: 17.9420
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     6.0000    2411.0000
#     77.0000    180550.0000
#   oddsratio: 5.8353
#   pvalue: 0.0008
# done.
# --> Not Suspect ICD Code: H40051
# --> Not Suspect ICD Code: 36565
# --> Not Suspect ICD Code: 53087
# --> Not Suspect ICD Code: S2232XG
#   chi2 test pvalue:
#     0.00334941
#   fisher test pvalue:
#     0.02623466
# start chi2 test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   expected:
#     0.0264    2416.9736
#     1.9736    180625.0264
#   chi2: 8.6066
#   pvalue: 0.0033
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     1.0000    2416.0000
#     1.0000    180626.0000
#   oddsratio: 74.7624
#   pvalue: 0.0262
# done.
# --> Not Suspect ICD Code: 6266
# --> Not Suspect ICD Code: O860
# --> Not Suspect ICD Code: S32010D
# --> Not Suspect ICD Code: E0110
# --> Not Suspect ICD Code: T84194A
# --> Not Suspect ICD Code: 71910
# --> Not Suspect ICD Code: 81602
# --> Not Suspect ICD Code: 79409
# --> Not Suspect ICD Code: D720
# --> Not Suspect ICD Code: 81321
# --> Not Suspect ICD Code: K5710
# --> Not Suspect ICD Code: M2548
# --> Not Suspect ICD Code: S01132S
# --> Not Suspect ICD Code: S42151A
# --> Not Suspect ICD Code: T7621XS
# --> Not Suspect ICD Code: 76870
# --> Not Suspect ICD Code: T2102XS
# --> Not Suspect ICD Code: Z006
#   chi2 test pvalue:
#     0.00256029
#   fisher test pvalue:
#     0.00104745
# start chi2 test
#   observed:
#     26.0000    2391.0000
#     3518.0000    177109.0000
#   expected:
#     46.7967    2370.2033
#     3497.2033    177129.7967
#   chi2: 9.0970
#   pvalue: 0.0026
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     26.0000    2391.0000
#     3518.0000    177109.0000
#   oddsratio: 0.5474
#   pvalue: 0.0010
# done.
# --> Not Suspect ICD Code: K3533
# --> Not Suspect ICD Code: D164
# --> Not Suspect ICD Code: V1003
# --> Not Suspect ICD Code: F40243
# --> Not Suspect ICD Code: J0140
# --> Not Suspect ICD Code: Y92213
# --> Not Suspect ICD Code: I83219
# --> Not Suspect ICD Code: S31001A
# --> Not Suspect ICD Code: 82391
# --> Not Suspect ICD Code: 6179
#   chi2 test pvalue:
#     0.00287841
#   fisher test pvalue:
#     0.00577213
# start chi2 test
#   observed:
#     8.0000    2409.0000
#     194.0000    180433.0000
#   expected:
#     2.6673    2414.3327
#     199.3327    180427.6673
#   chi2: 8.8830
#   pvalue: 0.0029
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     8.0000    2409.0000
#     194.0000    180433.0000
#   oddsratio: 3.0886
#   pvalue: 0.0058
# done.
# --> Not Suspect ICD Code: 20078
# --> Not Suspect ICD Code: R070
# --> Not Suspect ICD Code: T490X5A
# --> Not Suspect ICD Code: 4578
# --> Not Suspect ICD Code: A539
# --> Not Suspect ICD Code: S21139A
# --> Not Suspect ICD Code: S92201A
# --> Not Suspect ICD Code: 2529
# --> Not Suspect ICD Code: E8610
# --> Not Suspect ICD Code: C8286
# --> Not Suspect ICD Code: 8970
# --> Not Suspect ICD Code: I4949
# --> Not Suspect ICD Code: O6003
# --> Not Suspect ICD Code: 7028
# --> Not Suspect ICD Code: Y791
# --> Not Suspect ICD Code: S62342A
# --> Not Suspect ICD Code: I739
# --> Not Suspect ICD Code: D3A012
# --> Not Suspect ICD Code: 29600
# --> Not Suspect ICD Code: S6391XA
# --> Not Suspect ICD Code: C9150
# --> Not Suspect ICD Code: Y92198
# --> Not Suspect ICD Code: G9752
# --> Not Suspect ICD Code: 81600
# --> Not Suspect ICD Code: K2950
# --> Not Suspect ICD Code: 83903
# --> Not Suspect ICD Code: 5671
# --> Not Suspect ICD Code: S92344A
# --> Not Suspect ICD Code: 78491
# --> Not Suspect ICD Code: N6041
# --> Not Suspect ICD Code: M4723
# --> Not Suspect ICD Code: 37887
# --> Not Suspect ICD Code: R10814
# --> Not Suspect ICD Code: M7581
# --> Not Suspect ICD Code: G9612
# --> Not Suspect ICD Code: 86809
# --> Not Suspect ICD Code: V4365
#   chi2 test pvalue:
#     0.00000394
#   fisher test pvalue:
#     0.00001913
# start chi2 test
#   observed:
#     76.0000    2341.0000
#     3334.0000    177293.0000
#   expected:
#     45.0273    2371.9727
#     3364.9727    177262.0273
#   chi2: 21.2955
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     76.0000    2341.0000
#     3334.0000    177293.0000
#   oddsratio: 1.7264
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: F4522
# --> Not Suspect ICD Code: S52272A
# --> Not Suspect ICD Code: O6989X1
# --> Not Suspect ICD Code: 72142
# --> Not Suspect ICD Code: E8250
# --> Not Suspect ICD Code: I97630
# --> Not Suspect ICD Code: S68122A
# --> Not Suspect ICD Code: I237
# --> Not Suspect ICD Code: 33523
# --> Not Suspect ICD Code: 23773
# --> Not Suspect ICD Code: M24422
# --> Not Suspect ICD Code: G4761
# --> Not Suspect ICD Code: O6023X0
# --> Not Suspect ICD Code: S61205A
# --> Not Suspect ICD Code: E0150
# --> Not Suspect ICD Code: 25092
# --> Not Suspect ICD Code: S3600XD
# --> Not Suspect ICD Code: F10159
# --> Not Suspect ICD Code: L97819
# --> Not Suspect ICD Code: M9398
# --> Not Suspect ICD Code: D509
#   chi2 test pvalue:
#     0.00000009
#   fisher test pvalue:
#     0.00000083
# start chi2 test
#   observed:
#     90.0000    2327.0000
#     3824.0000    176803.0000
#   expected:
#     51.6823    2365.3177
#     3862.3177    176764.6823
#   chi2: 28.6555
#   pvalue: 0.0000
#   dof: 1.0000
# done.
# start fisher test
#   observed:
#     90.0000    2327.0000
#     3824.0000    176803.0000
#   oddsratio: 1.7882
#   pvalue: 0.0000
# done.
# --> Not Suspect ICD Code: 1701
# --> Not Suspect ICD Code: I6991
# --> Not Suspect ICD Code: W541XXA
# --> Not Suspect ICD Code: Y92049
# --> Not Suspect ICD Code: A5219
# --> Not Suspect ICD Code: Z9852
# --> Not Suspect ICD Code: C44702
# --> Not Suspect ICD Code: H9012
# --> Not Suspect ICD Code: S62605S
# --> Not Suspect ICD Code: S82002B
# --> Not Suspect ICD Code: V4762XA
# --> Not Suspect ICD Code: Z3A23
# --> Not Suspect ICD Code: S42202D
# --> Not Suspect ICD Code: V0183
# --> Not Suspect ICD Code: E8052
# --> Not Suspect ICD Code: S22029D
# --> Not Suspect ICD Code: N323
# --> Not Suspect ICD Code: 7109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/k/Repo/gp-ibd/scripts/statistics20231123_complications.ipynb 单元格 8 line 1
#       <a href='vscode-notebook-cell:/Users/k/Repo/gp-ibd/scripts/statistics20231123_complications.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> print('--> Not Suspect ICD Code: {}'.format(not_suspect_icd_code))
#       <a href='vscode-notebook-cell:/Users/k/Repo/gp-ibd/scripts/statistics20231123_complications.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> pvalue1 = construct_chi2_test(df_ibd, df_no_ibd, not_suspect_icd_code, silent=True)
# ---> <a href='vscode-notebook-cell:/Users/k/Repo/gp-ibd/scripts/statistics20231123_complications.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> pvalue2 = construct_fisher_test(df_ibd, df_no_ibd, not_suspect_icd_code, silent=True)
#      <a href='vscode-notebook-cell:/Users/k/Repo/gp-ibd/scripts/statistics20231123_complications.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> if pvalue1 <= 0.01 or pvalue2 <= 0.01:
#      <a href='vscode-notebook-cell:/Users/k/Repo/gp-ibd/scripts/statistics20231123_complications.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>     print('  chi2 test pvalue:\n    {:.8f}'.format(pvalue1))
#
# File ~/Repo/gp-ibd/scripts/utils_statistics.py:42, in construct_fisher_test(pos_df, neg_df, icd_code, silent)
#      40 b = len(who_not_get_this_disease(pos_df, icd_code))
#      41 c = len(who_get_this_disease(neg_df, icd_code))
# ---> 42 d = len(who_not_get_this_disease(neg_df, icd_code))
#      44 observed = np.array([[a, b], [c, d]])
#      45 oddsratio, pvalue = fisher_exact(observed)
#
# File ~/Repo/gp-ibd/scripts/utils_complications.py:15, in who_not_get_this_disease(_df, _icd_code)
#      13 def who_not_get_this_disease(_df, _icd_code) -> list:
#      14     patients_get_this_disease = who_get_this_disease(_df, _icd_code)
# ---> 15     patients_not_get_this_disease = list(set(_df['subject_id'].unique()) - set(patients_get_this_disease)) # neg unique = total unique - pos unique
#      16     return patients_not_get_this_disease
#
# File ~/Repo/gp-ibd/.venv/lib/python3.10/site-packages/pandas/core/series.py:2287, in Series.unique(self)
#    2224 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2225     """
#    2226     Return unique values of Series object.
#    2227
#    (...)
#    2285     Categories (3, object): ['a' < 'b' < 'c']
#    2286     """
# -> 2287     return super().unique()
#
# File ~/Repo/gp-ibd/.venv/lib/python3.10/site-packages/pandas/core/base.py:1025, in IndexOpsMixin.unique(self)
#    1023     result = values.unique()
#    1024 else:
# -> 1025     result = algorithms.unique1d(values)
#    1026 return result
#
# File ~/Repo/gp-ibd/.venv/lib/python3.10/site-packages/pandas/core/algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File ~/Repo/gp-ibd/.venv/lib/python3.10/site-packages/pandas/core/algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# KeyboardInterrupt:
